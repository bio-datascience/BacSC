# %%
# !pip install scanpy
# !pip install KDEpy
# !pip install leidenalg
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: scanpy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: anndata>=0.8 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.10.7)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.11.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.3.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.8.2)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.3)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.57.1+1.g1ff679645)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.24.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (23.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.5.3)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.6)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.12)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.2.0)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.12.0)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.0.0)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.14.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy) (4.66.1)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.6)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->scanpy) (1.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->scanpy) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.56->scanpy) (0.40.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->scanpy) (3.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy->scanpy) (1.16.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.10/dist-packages (from session-info->scanpy) (0.10.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: KDEpy in /usr/local/lib/python3.10/dist-packages (1.1.9)
# Requirement already satisfied: numpy<2.0,>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from KDEpy) (1.24.4)
# Requirement already satisfied: scipy<2.0,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from KDEpy) (1.12.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: leidenalg in /usr/local/lib/python3.10/dist-packages (0.10.2)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from leidenalg) (0.11.4)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.7.0)

# %%
import pandas as pd
import scanpy as sc
import anndata as ad
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.sparse as sps
import re

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import tools.util_probe as up
import tools.util as ut
import tools.NB_est as nb
import tools.countsplit as cs
import tools.scDEED as scd
import tools.clustering_opt as co

import warnings
warnings.filterwarnings("ignore")

# %%
import importlib

# %% [markdown]
# ## Preprocessing
# ### Read data

# %%
import gzip
import shutil
data_dir = "../../data/BacDrop/raw_data/"
file_names = ["GSM5456505_PsA_CDS.tsv"]

for f in file_names:
    file_name_full = data_dir + f

    if not f in os.listdir(data_dir):
        if f + ".gz" in os.listdir(data_dir):
            print("unzipping data...")
            with gzip.open(file_name_full + ".gz","rb") as f_in, open(file_name_full,"wb") as f_out:
                shutil.copyfileobj(f_in, f_out)
        else:
            raise FileNotFoundError(f"{f} does not exist in regular or zipped form")

# %%
adatas = []
for f in file_names:
    file_name_full = data_dir + f
    print(f)
    adata = sc.read_csv(file_name_full, delimiter="\t", first_column_names=True)
    adata = adata.transpose()
    adata.var_names_make_unique()
    adata.X = sps.csr_matrix(adata.X)
    adatas.append(adata)
    
adatas
# Out:
# GSM5456505_PsA_CDS.tsv
# [AnnData object with n_obs × n_vars = 8192 × 3478]

# %%
adatas[0].obs["species"] = "P.Aeruginosa"

# %%
data_untr = adatas[0]
data_untr
# Out:
# AnnData object with n_obs × n_vars = 8192 × 3478
#     obs: 'species'

# %%
print(f"Zero inflation of data: {((np.prod(data_untr.X.shape) - data_untr.X.getnnz()) / np.prod(data_untr.X.shape)).round(3)}")
# Out:
# Zero inflation of data: 0.999

# %% [markdown]
# ### Filter cells
#
# --> filter based on mean absolute standard deviation

# %%
importlib.reload(ut)
data_gene = data_untr.copy()
# sc.pp.filter_cells(data_gene, min_genes=15)
# sc.pp.filter_genes(data_gene, min_cells=2)
# sc.pp.calculate_qc_metrics(data_gene, var_type="genes", percent_top=None, log1p=True, inplace=True)

data_gene = ut.filter_outliers(data_untr, nmads=10, min_cells=2, min_genes=15)
# print(data_untr.obs.outlier.value_counts())
print(f"Total number of cells: {data_untr.n_obs}")
print(f"Number of cells after filtering: {data_gene.n_obs}")
data_gene
# Out:
# Total number of cells: 8192
# Number of cells after filtering: 103
# AnnData object with n_obs × n_vars = 103 × 628
#     obs: 'species', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'outlier', 'n_genes'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %%
g = sc.pl.scatter(data_untr, x='total_counts', y='n_genes_by_counts', color="outlier", show=False, size=15, color_map="flare", title="Sequencing depth of cells (before outlier removal)")
g.set(xlabel = "Sequencing depth")
g.set(ylabel="Number of unique genes")
plt.tight_layout()
plt.show()

sc.pl.scatter(data_gene, x='total_counts', y='n_genes_by_counts', show=False, size=15)
plt.title("Sequencing depth of cells (after outlier removal)")
plt.xlabel("Sequencing depth")
plt.ylabel("Number of unique genes")
plt.show()

# %% [markdown]
# ## Variance stabilization
#
# Plotting the mean-variance ratio of genes, we see that the data is clearly overdispersed. Therefore, we will use negative binomial count splitting

# %%
data_gene.layers["counts"] = data_gene.X.copy()

# %%
data_gene.var["var_counts"] = np.asarray(np.var(data_gene.X.toarray(), axis=0)).squeeze()
data_gene.var["mean_counts"] = np.asarray(np.mean(data_gene.X.toarray(), axis=0)).squeeze()
sns.scatterplot(data=data_gene.var, x="mean_counts", y="var_counts")
plt.plot([0, np.ceil(np.max(data_gene.var["mean_counts"]))], [0, np.ceil(np.max(data_gene.var["mean_counts"]))], color="red")
plt.title("Mean-variance relationship of genes")
plt.xlabel("Mean counts")
plt.ylabel("Variance")
plt.show()

# %%
mv_corr_lin = np.corrcoef(data_gene.var["mean_counts"], data_gene.var["var_counts"])[0,1]
mv_corr_sq = np.corrcoef(data_gene.var["mean_counts"]**2, data_gene.var["var_counts"])[0,1]

if mv_corr_sq > mv_corr_lin:
    is_overdispersed = True
else:
    is_overdispersed = False
    
print(is_overdispersed)
# Out:
# False

# %% [markdown]
# ## Estimate negative binomial parameters for each gene

# %%
importlib.reload(nb)
nb.estimate_overdisp_nb(data_gene, layer="counts", flavor="sctransform", seed=1234)

# %%
data_gene.var
# Out:
#                     n_cells_by_counts  mean_counts  log1p_mean_counts  \
# cds-NP_064721.1                     4     0.038835           0.038100
# cds-NP_064722.1                     5     0.048544           0.047402
# cds-NP_064723.1                     9     0.097087           0.092659
# cds-NP_064724.1                     7     0.077670           0.074801
# cds-NP_064728.1                     3     0.029126           0.028710
# ...                               ...          ...                ...
# cds-NP_254251.1                     2     0.019417           0.019231
# cds-NP_254252.1                     3     0.029126           0.028710
# cds-NP_254255.1                     6     0.058252           0.056619
# cds-NP_254256.1                     4     0.048544           0.047402
# cds-YP_003933614.1                  7     0.067961           0.065751
#
#                     pct_dropout_by_counts  total_counts  log1p_total_counts  \
# cds-NP_064721.1                 96.116505           4.0            1.609438
# cds-NP_064722.1                 95.145631           5.0            1.791759
# cds-NP_064723.1                 91.262136          10.0            2.397895
# cds-NP_064724.1                 93.203883           8.0            2.197225
# cds-NP_064728.1                 97.087379           3.0            1.386294
# ...                                   ...           ...                 ...
# cds-NP_254251.1                 98.058252           2.0            1.098612
# cds-NP_254252.1                 97.087379           3.0            1.386294
# cds-NP_254255.1                 94.174757           6.0            1.945910
# cds-NP_254256.1                 96.116505           5.0            1.791759
# cds-YP_003933614.1              93.203883           7.0            2.079442
#
#                     n_cells  var_counts  is_scd_outlier  nb_overdisp  \
# cds-NP_064721.1           4    0.037327           False     1.857411
# cds-NP_064722.1           5    0.046187           False     2.081593
# cds-NP_064723.1           9    0.107079           False     1.723821
# cds-NP_064724.1           7    0.091055           False     0.936126
# cds-NP_064728.1           3    0.028278           False     1.490733
# ...                     ...         ...             ...          ...
# cds-NP_254251.1           2    0.019040           False     1.325248
# cds-NP_254252.1           3    0.028278           False     1.490733
# cds-NP_254255.1           6    0.054859           False     2.264633
# cds-NP_254256.1           4    0.065605           False     0.271008
# cds-YP_003933614.1        7    0.063342           False     3.020763
#
#                     nb_overdisp_cutoff   nb_mean    nb_umi  \
# cds-NP_064721.1               1.857411 -6.847968  2.232680
# cds-NP_064722.1               2.081593 -7.334481  2.674070
# cds-NP_064723.1               1.723821 -6.441060  2.611703
# cds-NP_064724.1               0.936126 -7.335830  2.927150
# cds-NP_064728.1               1.490733 -7.522283  2.396493
# ...                                ...       ...       ...
# cds-NP_254251.1               1.325248 -7.800279  2.151045
# cds-NP_254252.1               1.490733 -7.522283  2.396493
# cds-NP_254255.1               2.264633 -5.411588  1.690279
# cds-NP_254256.1               0.271008 -8.881512  3.548233
# cds-YP_003933614.1            3.020763 -5.511342  1.847371
#
#                     Intercept_step1_sct  log_umi_step1_sct  \
# cds-NP_064721.1               -1.752796          -1.118071
# cds-NP_064722.1               -2.733380          -0.210798
# cds-NP_064723.1               -5.550721           2.101033
# cds-NP_064724.1               -9.036007           3.946016
# cds-NP_064728.1               -6.324967           1.841094
# ...                                 ...                ...
# cds-NP_254251.1              -11.434734           4.488240
# cds-NP_254252.1               -6.458807           1.922612
# cds-NP_254255.1               -6.257439           2.217862
# cds-NP_254256.1               -3.500388           0.335284
# cds-YP_003933614.1            -4.771699           1.401997
#
#                     dispersion_step1_sct
# cds-NP_064721.1                 0.006086
# cds-NP_064722.1                 0.006088
# cds-NP_064723.1                 0.016571
# cds-NP_064724.1                 0.021355
# cds-NP_064728.1                 0.005656
# ...                                  ...
# cds-NP_254251.1                 0.001294
# cds-NP_254252.1                 0.006917
# cds-NP_254255.1                 0.009873
# cds-NP_254256.1                 0.114800
# cds-YP_003933614.1              0.006793
#
# [628 rows x 16 columns]

# %%
sns.histplot(data=data_gene.var, x="nb_overdisp_cutoff", bins=100)
plt.title("Overdispersion parameters estimated by scTransform")
plt.xlabel("Overdispersion parameter")
plt.show()

g = sns.scatterplot(data=data_gene.var, y="nb_overdisp_cutoff", x="mean_counts")
g.set(xscale="log", yscale="log")
plt.title("Overdispersion parameters estimated by scTransform")
plt.xlabel("Gene mean")
plt.ylabel("Theta")
plt.show()

# %%
data_gene.X = data_gene.layers["counts"].copy()

# %% [markdown]
# ## Normalization, VST, scaling and PCA

# %%
sc.pp.normalize_total(data_gene, target_sum=None, layer=None)
if is_overdispersed:
    data_gene.X = sps.csr_matrix(np.log(data_gene.X.toarray() + np.array(data_gene.var["nb_overdisp_cutoff"] / 4)))
else:
    # data_gene.X = sps.csr_matrix(np.sqrt(data_gene.X.toarray()))
    data_gene.X = sps.csr_matrix(np.log(data_gene.X.toarray() + np.array(data_gene.var["nb_overdisp_cutoff"] / 4)))

data_gene.layers["vst_counts"] = data_gene.X.copy()
sc.pp.scale(data_gene, max_value=10, zero_center=True)
# data_gene.X[np.isnan(data_gene.X)] = 0
sc.tl.pca(data_gene, svd_solver='arpack')

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 5))
p1 = sns.histplot(data_gene.obs, x="total_counts", kde=False, ax=axes[0], multiple="stack")
axes[0].set_title("Total counts")
data_gene.obs["total_counts_norm"] = data_gene.layers["vst_counts"].sum(1)
p2 = sns.histplot(data_gene.obs, x="total_counts_norm", kde=False, ax=axes[1], multiple="stack")
axes[1].set_title("Shifted logarithm")
data_gene.obs["total_counts_scale"] = data_gene.X.sum(1)
p2 = sns.histplot(data_gene.obs, x="total_counts_scale", kde=False, ax=axes[2], multiple="stack")
axes[2].set_title("VST and scaled")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Count-splitting into train and test data

# %%
if is_overdispersed:
    data_dist = "NB"
else:
    data_dist = "Poi"
data_train, data_test = cs.countsplit_adata(data_gene, data_dist=data_dist, beta_key="nb_overdisp_cutoff", layer="counts", min_genes=1, max_counts=1e9, seed=1234)
print(data_train)
# Out:
# AnnData object with n_obs × n_vars = 103 × 191
#     obs: 'species', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'outlier', 'n_genes', 'total_counts_norm', 'total_counts_scale', 'n_counts', 'n_PCs_by_counts', 'log1p_n_PCs_by_counts'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'var_counts', 'is_scd_outlier', 'nb_overdisp', 'nb_overdisp_cutoff', 'nb_mean', 'nb_umi', 'Intercept_step1_sct', 'log_umi_step1_sct', 'dispersion_step1_sct', 'mean', 'std'
#     layers: 'counts'

# %%
# Transformation, centering and PCA
sc.pp.normalize_total(data_train, target_sum=None, layer=None)
if is_overdispersed:
    data_train.X = sps.csr_matrix(np.log(data_train.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
else:
    # data_train.X = sps.csr_matrix(np.sqrt(data_train.X.toarray()))
    data_train.X = sps.csr_matrix(np.log(data_train.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
data_train.layers["vst_counts"] = data_train.X.copy()
sc.pp.scale(data_train, max_value=10, zero_center=True)
sc.tl.pca(data_train, svd_solver='arpack')


sc.pp.normalize_total(data_test, target_sum=None, layer=None)
if is_overdispersed:
    data_test.X = sps.csr_matrix(np.log(data_test.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
else:
    # data_test.X = sps.csr_matrix(np.sqrt(data_test.X.toarray()))
    data_test.X = sps.csr_matrix(np.log(data_test.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
data_test.layers["vst_counts"] = data_test.X.copy()
sc.pp.scale(data_test, max_value=10, zero_center=True)
sc.tl.pca(data_test, svd_solver='arpack')

# %%
sc.pl.pca(data_train, title="Training data")
plt.show()

sc.pl.pca(data_test, title="Test data")
plt.show()

# %% [markdown]
# ### Principal component selection

# %%
k_errors, k_opt = cs.select_n_pcs_countsplit(data_train, data_test)
print(f"Optimal number of PCs:{k_opt}")
# Out:
# Optimal number of PCs:1

# %%
plt.scatter(np.arange(20) + 1, k_errors)
plt.title("SVD loss")
plt.xlabel("Dimensionality")
plt.ylabel("Loss")
plt.show()

# %%
sc.pl.pca(data_gene, color="total_counts", cmap="viridis", title="PCA of full dataset")
plt.show()

# %%
data_gene.uns["BacSC_params"] = {"k_opt": k_opt}

# %% [markdown]
# ## Selection of optimal number of neighbors and optimal UMAP scale via scDEED

# %%
rng = np.random.default_rng()
seed = rng.choice(1000)
seed=818
print(seed)
# Out:
# 818

# %%
importlib.reload(scd)

n_neighborss = [10, 15, 20, 25, 30, 35, 40, 45, 50, 60, 70, 80, 90, 100, 150, 200, 250]
min_dists = [0.05, 0.1, 0.3, 0.5, 0.7]

scdeed_result, rel_scores, null_rel_scores, reliabilities, n_neighbors_opt, min_dist_opt = scd.scdeed_parameter_selection(data_gene, n_neighborss, min_dists, n_pcs=k_opt, rng_seed=seed, embedding_method="UMAP", similarity_percent=0.5, save_path="Pseudomonas_4species_scdeed")
# Out:
# calculating (10, 0.05) - run 1/85
# calculating (10, 0.1) - run 2/85
# calculating (10, 0.3) - run 3/85
# calculating (10, 0.5) - run 4/85
# calculating (10, 0.7) - run 5/85
# calculating (15, 0.05) - run 6/85
# calculating (15, 0.1) - run 7/85
# calculating (15, 0.3) - run 8/85
# calculating (15, 0.5) - run 9/85
# calculating (15, 0.7) - run 10/85
# calculating (20, 0.05) - run 11/85
# calculating (20, 0.1) - run 12/85
# calculating (20, 0.3) - run 13/85
# calculating (20, 0.5) - run 14/85
# calculating (20, 0.7) - run 15/85
# calculating (25, 0.05) - run 16/85
# calculating (25, 0.1) - run 17/85
# calculating (25, 0.3) - run 18/85
# calculating (25, 0.5) - run 19/85
# calculating (25, 0.7) - run 20/85
# calculating (30, 0.05) - run 21/85
# calculating (30, 0.1) - run 22/85
# calculating (30, 0.3) - run 23/85
# calculating (30, 0.5) - run 24/85
# calculating (30, 0.7) - run 25/85
# calculating (35, 0.05) - run 26/85
# calculating (35, 0.1) - run 27/85
# calculating (35, 0.3) - run 28/85
# calculating (35, 0.5) - run 29/85
# calculating (35, 0.7) - run 30/85
# calculating (40, 0.05) - run 31/85
# calculating (40, 0.1) - run 32/85
# calculating (40, 0.3) - run 33/85
# calculating (40, 0.5) - run 34/85
# calculating (40, 0.7) - run 35/85
# calculating (45, 0.05) - run 36/85
# calculating (45, 0.1) - run 37/85
# calculating (45, 0.3) - run 38/85
# calculating (45, 0.5) - run 39/85
# calculating (45, 0.7) - run 40/85
# calculating (50, 0.05) - run 41/85
# calculating (50, 0.1) - run 42/85
# calculating (50, 0.3) - run 43/85
# calculating (50, 0.5) - run 44/85
# calculating (50, 0.7) - run 45/85
# calculating (60, 0.05) - run 46/85
# calculating (60, 0.1) - run 47/85
# calculating (60, 0.3) - run 48/85
# calculating (60, 0.5) - run 49/85
# calculating (60, 0.7) - run 50/85
# calculating (70, 0.05) - run 51/85
# calculating (70, 0.1) - run 52/85
# calculating (70, 0.3) - run 53/85
# calculating (70, 0.5) - run 54/85
# calculating (70, 0.7) - run 55/85
# calculating (80, 0.05) - run 56/85
# calculating (80, 0.1) - run 57/85
# calculating (80, 0.3) - run 58/85
# calculating (80, 0.5) - run 59/85
# calculating (80, 0.7) - run 60/85
# calculating (90, 0.05) - run 61/85
# calculating (90, 0.1) - run 62/85
# calculating (90, 0.3) - run 63/85
# calculating (90, 0.5) - run 64/85
# calculating (90, 0.7) - run 65/85
# calculating (100, 0.05) - run 66/85
# calculating (100, 0.1) - run 67/85
# calculating (100, 0.3) - run 68/85
# calculating (100, 0.5) - run 69/85
# calculating (100, 0.7) - run 70/85
# calculating (150, 0.05) - run 71/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (150, 0.1) - run 72/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (150, 0.3) - run 73/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (150, 0.5) - run 74/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (150, 0.7) - run 75/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (200, 0.05) - run 76/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (200, 0.1) - run 77/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (200, 0.3) - run 78/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (200, 0.5) - run 79/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (200, 0.7) - run 80/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (250, 0.05) - run 81/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (250, 0.1) - run 82/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (250, 0.3) - run 83/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (250, 0.5) - run 84/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# calculating (250, 0.7) - run 85/85
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`
# WARNING: n_obs too small: adjusting to `n_neighbors = 52`

# %%
print(f"Optimal number of neighbors: {n_neighbors_opt}")
print(f"Optimal min_dist: {min_dist_opt}")

sns.lineplot(data=scdeed_result, x="n_neighbors", y="num_dubious", hue="min_dist", palette="tab10")
plt.title("scDEED results")
plt.ylabel("Number of dubiously embedded cells")
plt.show()
# Out:
# Optimal number of neighbors: 15
# Optimal min_dist: 0.05

# %%
# k_opt = data_gene.uns["BacSC_params"]["k_opt"]
# n_neighbors_opt = data_gene.uns["BacSC_params"]["n_neighbors_opt"]
# min_dist_opt = data_gene.uns["BacSC_params"]["min_dist_opt"]


# k_opt = 2
# n_neighbors_opt = 80
# min_dist_opt = 0.1

# %%
data_gene.uns["BacSC_params"]["n_neighbors_opt"] = n_neighbors_opt
data_gene.uns["BacSC_params"]["min_dist_opt"] = min_dist_opt

# %%
sc.pp.neighbors(data_gene, n_neighbors=n_neighbors_opt, n_pcs=k_opt)
sc.tl.umap(data_gene, neighbors_key="neighbors", min_dist=min_dist_opt, spread=1, random_state=3456)

# %%
sc.pl.umap(data_gene, color="embedding_reliability", alpha=1)
plt.show()

sc.pl.umap(data_gene, color="total_counts", alpha=1, cmap="viridis")
plt.show()

# %%
data_path = "../../data/BacDrop"

data_gene.write(data_path + "/pseudomonas_data_processed.h5ad")

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### Train/test-split for clustering

# %%
sc.pp.neighbors(data_train, n_neighbors=n_neighbors_opt, n_pcs=k_opt)
sc.tl.umap(data_train, neighbors_key="neighbors", min_dist=min_dist_opt, spread=1, random_state=1234)

sc.pp.neighbors(data_test, n_neighbors=n_neighbors_opt, n_pcs=k_opt)
sc.tl.umap(data_test, neighbors_key="neighbors", min_dist=min_dist_opt, spread=1, random_state=1234)


theta_opt, mirror_opt, umap_2_opt, ssd = ut.find_opt_umap_rotation(data_train.obsm["X_umap"].copy(), data_test.obsm["X_umap"].copy())
data_test.obsm["X_umap_rot"] = umap_2_opt

# %%
sc.pl.umap(data_train, color="total_counts", cmap="viridis", title="Training data")
plt.show()

sc.pl.embedding(data_test, basis="X_umap_rot", color="total_counts", cmap="viridis", title="Test data")
plt.show()

# %% [markdown]
# ### Apply clustering with array of resolutions

# %%
importlib.reload(co)
res_min = 0.01
res_max = 0.5
res_step = 0.02
resolutions = np.round(np.arange(res_min, res_max, res_step), 2)

co.cluster_train_test(data_train, data_test, resolutions, alg="leiden", random_state=1234)

# %%
for resolution in resolutions:
    fig, ax = plt.subplots(1, 2, figsize=(8, 3))
    sc.pl.umap(data_train, color=f"leiden_res{resolution}", ax=ax[0], title=f"Train data, resolution {resolution}", show=False)
    sc.pl.embedding(data_test, basis="X_umap_rot", color=f"leiden_res{resolution}", ax=ax[1], title=f"Test data, resolution {resolution}", show=False)
    ax[1].set_xlabel("UMAP1")
    ax[1].set_ylabel("UMAP2")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Modularities

# %%
importlib.reload(co)
mod_df, mod_df_wide, res_opt = co.find_optimal_clustering_resolution(data_train, data_test, resolutions, random_seed=1234)

print(f"Optimal resolution {res_opt}")
data_gene.uns["BacSC_params"]["res_opt"] = res_opt
# Out:
# resolution: 0.01 - clusters: 1 - Train: 0.49 - Test: 0.49 - Random: 0.49
# resolution: 0.03 - clusters: 2 - Train: 0.468 - Test: 0.241 - Random: 0.232
# resolution: 0.05 - clusters: 2 - Train: 0.457 - Test: 0.231 - Random: 0.219
# resolution: 0.07 - clusters: 2 - Train: 0.447 - Test: 0.221 - Random: 0.225
# resolution: 0.09 - clusters: 2 - Train: 0.437 - Test: 0.211 - Random: 0.209
# resolution: 0.11 - clusters: 3 - Train: 0.419 - Test: 0.165 - Random: 0.128
# resolution: 0.13 - clusters: 2 - Train: 0.417 - Test: 0.191 - Random: 0.179
# resolution: 0.15 - clusters: 3 - Train: 0.406 - Test: 0.151 - Random: 0.105
# resolution: 0.17 - clusters: 3 - Train: 0.399 - Test: 0.144 - Random: 0.104
# resolution: 0.19 - clusters: 4 - Train: 0.382 - Test: 0.097 - Random: 0.071
# resolution: 0.21 - clusters: 4 - Train: 0.376 - Test: 0.092 - Random: 0.089
# resolution: 0.23 - clusters: 4 - Train: 0.371 - Test: 0.087 - Random: 0.068
# resolution: 0.25 - clusters: 4 - Train: 0.366 - Test: 0.082 - Random: 0.061
# resolution: 0.27 - clusters: 4 - Train: 0.36 - Test: 0.076 - Random: 0.047
# resolution: 0.29 - clusters: 4 - Train: 0.355 - Test: 0.071 - Random: 0.047
# resolution: 0.31 - clusters: 4 - Train: 0.35 - Test: 0.066 - Random: 0.038
# resolution: 0.33 - clusters: 4 - Train: 0.345 - Test: 0.061 - Random: 0.046
# resolution: 0.35 - clusters: 4 - Train: 0.339 - Test: 0.056 - Random: 0.042
# resolution: 0.37 - clusters: 4 - Train: 0.334 - Test: 0.051 - Random: 0.039
# resolution: 0.39 - clusters: 4 - Train: 0.329 - Test: 0.045 - Random: 0.025
# resolution: 0.41 - clusters: 5 - Train: 0.334 - Test: 0.044 - Random: 0.016
# resolution: 0.43 - clusters: 5 - Train: 0.33 - Test: 0.04 - Random: 0.013
# resolution: 0.45 - clusters: 5 - Train: 0.326 - Test: 0.036 - Random: 0.005
# resolution: 0.47 - clusters: 5 - Train: 0.322 - Test: 0.032 - Random: 0.001
# resolution: 0.49 - clusters: 5 - Train: 0.318 - Test: 0.028 - Random: -0.004
# Optimal resolution 0.15

# %%
sns.lineplot(data=mod_df, x="resolution", y="score", hue="type")
plt.title("Clustering modularities")
plt.xlabel("Resolution")
plt.ylabel("Modularity")
plt.show()

# %%
sns.lineplot(data=mod_df_wide, x="resolution", y="diff_rand_test")
plt.title("Clustering modularities")
plt.xlabel("Resolution")
plt.ylabel("Difference Test-Random")
plt.show()

# %%
result_path = "Pseudomonas_4species_clustering"
if not os.path.exists(result_path):
    os.makedirs(result_path)
    
mod_df.to_csv(result_path + "/modularities.csv")
mod_df_wide.to_csv(result_path + "/modularities_wide.csv")

# %% [markdown]
# ## Cluster analysis
#
# Optimal Leiden resolution: Maximal difference between random and test

# %%
sc.tl.leiden(data_gene, resolution=res_opt, key_added="leiden_opt")

# %%
sc.pl.umap(data_gene, color="leiden_opt", palette="tab10", title="Sample 3")
plt.show()

# %%
data_gene.write(data_path + "/pseudomonas_data_processed.h5ad")

# %%
sc.pl.scatter(data_gene, x='total_counts', y='n_genes_by_counts', show=False, size=15, color="leiden_opt")
plt.title("Sequencing depth of cells (after outlier removal)")
plt.xlabel("Sequencing depth")
plt.ylabel("Number of unique genes")
plt.show()

# %%
sc.tl.rank_genes_groups(data_gene, 'leiden_opt', method='wilcoxon')
sc.pl.rank_genes_groups(data_gene, n_genes=25, sharey=False)

# %%
nclust = len(np.unique(data_gene.obs["leiden_opt"]))

for i in range(nclust):
    sc.pl.rank_genes_groups_violin(data_gene, groups=str(i), n_genes=10)

# %% [markdown]
# ## Attach feature table

# %%
data_path = "../../data/BacDrop/"
data_gene = sc.read_h5ad(data_path + "/pseudomonas_data_processed.h5ad")
data_gene
# Out:
# AnnData object with n_obs × n_vars = 103 × 628
#     obs: 'species', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'outlier', 'n_genes', 'total_counts_norm', 'total_counts_scale', 'embedding_reliability', 'reliability_score', 'null_reliability_score', 'leiden_opt'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'var_counts', 'is_scd_outlier', 'nb_overdisp', 'nb_overdisp_cutoff', 'nb_mean', 'nb_umi', 'Intercept_step1_sct', 'log_umi_step1_sct', 'dispersion_step1_sct', 'mean', 'std'
#     uns: 'BacSC_params', 'embedding_reliability_colors', 'leiden_opt', 'leiden_opt_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'vst_counts'
#     obsp: 'connectivities', 'distances'

# %%
feature_table = pd.read_csv(data_path + "genomic_information/pseudomonas_pao1/GCF_000006765.1_ASM676v1_feature_table.txt", sep="\t")
feature_table = feature_table[feature_table["# feature"] == "CDS"][["locus_tag", "product_accession", "name", "symbol"]]

feature_table
# Out:
#       locus_tag product_accession  \
# 1        PA0001       NP_064721.1
# 3        PA0002       NP_064722.1
# 5        PA0003       NP_064723.1
# 7        PA0004       NP_064724.1
# 9        PA0005       NP_064725.1
# ...         ...               ...
# 11366    PA5566       NP_254253.1
# 11368    PA5567       NP_254254.1
# 11370    PA5568       NP_254255.1
# 11372    PA5569       NP_254256.1
# 11374    PA5570       NP_254257.1
#
#                                                   name symbol
# 1                chromosome replication initiator DnaA   dnaA
# 3                      DNA polymerase III subunit beta   dnaN
# 5              DNA replication and repair protein RecF   recF
# 7                                 DNA gyrase subunit B   gyrB
# 9                lysophosphatidic acid acyltransferase   lptA
# ...                                                ...    ...
# 11366                             hypothetical protein    NaN
# 11368                    tRNA modification GTPase TrmE    NaN
# 11370  inner membrane protein translocase subunit YidC    NaN
# 11372                                   ribonuclease P   rnpA
# 11374                        50S ribosomal protein L34   rpmH
#
# [5572 rows x 4 columns]

# %%
ind = data_gene.var.index

data_gene.var["lt"] = [x.removeprefix('cds-') for x in data_gene.var.index]
data_gene.var["lt"] = [re.sub(r"-[0-9]+", "", x) for x in data_gene.var["lt"]]

df3=data_gene.var.reset_index().merge(feature_table, how='left', left_on='lt', right_on='locus_tag', suffixes=(None, "_y")).drop_duplicates("index").set_index("index")
df4=data_gene.var.reset_index().merge(feature_table, how='left', left_on='lt', right_on='product_accession', suffixes=(None, "_y")).drop_duplicates("index").set_index("index")
df5 = pd.merge(df3, df4, how="outer", left_index=True, right_index=True, suffixes=(None, "_y"))
print(df5)

df5.locus_tag.fillna(df5.locus_tag_y, inplace=True)
df5.product_accession.fillna(df5.product_accession_y, inplace=True)
df5.name.fillna(df5.name_y, inplace=True)
df5.symbol.fillna(df5.symbol_y, inplace=True)

df5 = df5.loc[:,~df5.columns.str.endswith('_y')]

mdf = data_gene.var.merge(df5, how="left", left_index=True, right_index=True, suffixes=(None, "_y"))
mdf = mdf.loc[:,~mdf.columns.str.endswith('_y')]
data_gene.var
data_gene.var = mdf
# Out:
#                     n_cells_by_counts  mean_counts  log1p_mean_counts  \
# index
# cds-NP_064721.1                     4     0.038835           0.038100
# cds-NP_064722.1                     5     0.048544           0.047402
# cds-NP_064723.1                     9     0.097087           0.092659
# cds-NP_064724.1                     7     0.077670           0.074801
# cds-NP_064728.1                     3     0.029126           0.028710
# ...                               ...          ...                ...
# cds-NP_254251.1                     2     0.019417           0.019231
# cds-NP_254252.1                     3     0.029126           0.028710
# cds-NP_254255.1                     6     0.058252           0.056619
# cds-NP_254256.1                     4     0.048544           0.047402
# cds-YP_003933614.1                  7     0.067961           0.065751
#
#                     pct_dropout_by_counts  total_counts  log1p_total_counts  \
# index
# cds-NP_064721.1                 96.116505           4.0            1.609438
# cds-NP_064722.1                 95.145631           5.0            1.791759
# cds-NP_064723.1                 91.262136          10.0            2.397895
# cds-NP_064724.1                 93.203883           8.0            2.197225
# cds-NP_064728.1                 97.087379           3.0            1.386294
# ...                                   ...           ...                 ...
# cds-NP_254251.1                 98.058252           2.0            1.098612
# cds-NP_254252.1                 97.087379           3.0            1.386294
# cds-NP_254255.1                 94.174757           6.0            1.945910
# cds-NP_254256.1                 96.116505           5.0            1.791759
# cds-YP_003933614.1              93.203883           7.0            2.079442
#
#                     n_cells  var_counts  is_scd_outlier  nb_overdisp  ...  \
# index                                                                 ...
# cds-NP_064721.1           4    0.037327           False     1.857411  ...
# cds-NP_064722.1           5    0.046187           False     2.081593  ...
# cds-NP_064723.1           9    0.107079           False     1.723821  ...
# cds-NP_064724.1           7    0.091055           False     0.936126  ...
# cds-NP_064728.1           3    0.028278           False     1.490733  ...
# ...                     ...         ...             ...          ...  ...
# cds-NP_254251.1           2    0.019040           False     1.325248  ...
# cds-NP_254252.1           3    0.028278           False     1.490733  ...
# cds-NP_254255.1           6    0.054859           False     2.264633  ...
# cds-NP_254256.1           4    0.065605           False     0.271008  ...
# cds-YP_003933614.1        7    0.063342           False     3.020763  ...
#
#                     Intercept_step1_sct_y  log_umi_step1_sct_y  \
# index
# cds-NP_064721.1                 -1.752796            -1.118071
# cds-NP_064722.1                 -2.733380            -0.210798
# cds-NP_064723.1                 -5.550721             2.101033
# cds-NP_064724.1                 -9.036007             3.946016
# cds-NP_064728.1                 -6.324967             1.841094
# ...                                   ...                  ...
# cds-NP_254251.1                -11.434734             4.488240
# cds-NP_254252.1                 -6.458807             1.922612
# cds-NP_254255.1                 -6.257439             2.217862
# cds-NP_254256.1                 -3.500388             0.335284
# cds-YP_003933614.1              -4.771699             1.401997
#
#                     dispersion_step1_sct_y    mean_y     std_y  \
# index
# cds-NP_064721.1                   0.006086 -0.723134  0.228897
# cds-NP_064722.1                   0.006088 -0.602891  0.257226
# cds-NP_064723.1                   0.016571 -0.776145  0.243638
# cds-NP_064724.1                   0.021355 -1.393910  0.246812
# cds-NP_064728.1                   0.005656 -0.964216  0.141742
# ...                                    ...       ...       ...
# cds-NP_254251.1                   0.001294 -1.094273  0.074433
# cds-NP_254252.1                   0.006917 -0.963500  0.154831
# cds-NP_254255.1                   0.009873 -0.532524  0.185470
# cds-NP_254256.1                   0.114800 -2.597857  0.495965
# cds-YP_003933614.1                0.006793 -0.242225  0.169935
#
#                               lt_y  locus_tag_y  product_accession_y  \
# index
# cds-NP_064721.1        NP_064721.1       PA0001          NP_064721.1
# cds-NP_064722.1        NP_064722.1       PA0002          NP_064722.1
# cds-NP_064723.1        NP_064723.1       PA0003          NP_064723.1
# cds-NP_064724.1        NP_064724.1       PA0004          NP_064724.1
# cds-NP_064728.1        NP_064728.1       PA0008          NP_064728.1
# ...                            ...          ...                  ...
# cds-NP_254251.1        NP_254251.1       PA5564          NP_254251.1
# cds-NP_254252.1        NP_254252.1       PA5565          NP_254252.1
# cds-NP_254255.1        NP_254255.1       PA5568          NP_254255.1
# cds-NP_254256.1        NP_254256.1       PA5569          NP_254256.1
# cds-YP_003933614.1  YP_003933614.1       PA4812       YP_003933614.1
#
#                                                                name_y symbol_y
# index
# cds-NP_064721.1                 chromosome replication initiator DnaA     dnaA
# cds-NP_064722.1                       DNA polymerase III subunit beta     dnaN
# cds-NP_064723.1               DNA replication and repair protein RecF     recF
# cds-NP_064724.1                                  DNA gyrase subunit B     gyrB
# cds-NP_064728.1                     glycine--tRNA ligase subunit beta     glyS
# ...                                                               ...      ...
# cds-NP_254251.1                       16S rRNA methyltransferase GidB     gidB
# cds-NP_254252.1     tRNA uridine 5-carboxymethylaminomethyl modifi...     gidA
# cds-NP_254255.1       inner membrane protein translocase subunit YidC      NaN
# cds-NP_254256.1                                        ribonuclease P     rnpA
# cds-YP_003933614.1              formate dehydrogenase-O major subunit     fdnG
#
# [628 rows x 46 columns]

# %%
sc.tl.rank_genes_groups(data_gene, 'leiden_opt', method='wilcoxon')
sc.pl.rank_genes_groups(data_gene, n_genes=25, sharey=False)

# %%
top_genes = [x[0] for x in data_gene.uns["rank_genes_groups"]["names"]]
print(data_gene.var.loc[top_genes[:25], :])
# Out:
#                  n_cells_by_counts  mean_counts  log1p_mean_counts  \
# cds-NP_252947.1                 29     0.407767           0.342005
# cds-NP_252390.1                  5     0.058252           0.056619
# cds-NP_251877.1                  3     0.029126           0.028710
# cds-NP_250029.1                  3     0.029126           0.028710
# cds-NP_253137.1                  4     0.038835           0.038100
# cds-NP_248707.1                  4     0.038835           0.038100
# cds-NP_252145.1                  4     0.038835           0.038100
# cds-NP_250461.1                  7     0.067961           0.065751
# cds-NP_249783.1                 35     0.466019           0.382551
# cds-NP_251331.1                  2     0.019417           0.019231
# cds-NP_252659.1                  2     0.019417           0.019231
# cds-NP_253931.1                  2     0.019417           0.019231
# cds-NP_253887.1                  2     0.019417           0.019231
# cds-NP_254031.1                  2     0.019417           0.019231
# cds-NP_251541.1                  2     0.019417           0.019231
# cds-NP_249343.1                  2     0.019417           0.019231
# cds-NP_254116.1                  2     0.019417           0.019231
# cds-NP_250925.1                  2     0.019417           0.019231
# cds-NP_251683.1                  2     0.019417           0.019231
# cds-NP_249008.1                  2     0.029126           0.028710
# cds-NP_248996.1                  2     0.019417           0.019231
# cds-NP_253920.1                  2     0.019417           0.019231
# cds-NP_253623.1                  2     0.019417           0.019231
# cds-NP_253266.1                  2     0.019417           0.019231
# cds-NP_249398.1                  2     0.019417           0.019231
#
#                  pct_dropout_by_counts  total_counts  log1p_total_counts  \
# cds-NP_252947.1              71.844660          42.0            3.761200
# cds-NP_252390.1              95.145631           6.0            1.945910
# cds-NP_251877.1              97.087379           3.0            1.386294
# cds-NP_250029.1              97.087379           3.0            1.386294
# cds-NP_253137.1              96.116505           4.0            1.609438
# cds-NP_248707.1              96.116505           4.0            1.609438
# cds-NP_252145.1              96.116505           4.0            1.609438
# cds-NP_250461.1              93.203883           7.0            2.079442
# cds-NP_249783.1              66.019417          48.0            3.891820
# cds-NP_251331.1              98.058252           2.0            1.098612
# cds-NP_252659.1              98.058252           2.0            1.098612
# cds-NP_253931.1              98.058252           2.0            1.098612
# cds-NP_253887.1              98.058252           2.0            1.098612
# cds-NP_254031.1              98.058252           2.0            1.098612
# cds-NP_251541.1              98.058252           2.0            1.098612
# cds-NP_249343.1              98.058252           2.0            1.098612
# cds-NP_254116.1              98.058252           2.0            1.098612
# cds-NP_250925.1              98.058252           2.0            1.098612
# cds-NP_251683.1              98.058252           2.0            1.098612
# cds-NP_249008.1              98.058252           3.0            1.386294
# cds-NP_248996.1              98.058252           2.0            1.098612
# cds-NP_253920.1              98.058252           2.0            1.098612
# cds-NP_253623.1              98.058252           2.0            1.098612
# cds-NP_253266.1              98.058252           2.0            1.098612
# cds-NP_249398.1              98.058252           2.0            1.098612
#
#                  n_cells  var_counts  is_scd_outlier  nb_overdisp  ...  \
# cds-NP_252947.1       29    0.532755           False     2.970292  ...
# cds-NP_252390.1        5    0.074277           False     0.175391  ...
# cds-NP_251877.1        3    0.028278           False     1.490733  ...
# cds-NP_250029.1        3    0.028278           False     1.490733  ...
# cds-NP_253137.1        4    0.037327           False     1.857411  ...
# cds-NP_248707.1        4    0.037327           False     1.857411  ...
# cds-NP_252145.1        4    0.037327           False     1.857411  ...
# cds-NP_250461.1        7    0.063342           False     3.020763  ...
# cds-NP_249783.1       35    0.598360           False     9.985682  ...
# cds-NP_251331.1        2    0.019040           False     1.325248  ...
# cds-NP_252659.1        2    0.019040           False     1.325248  ...
# cds-NP_253931.1        2    0.019040           False     1.325248  ...
# cds-NP_253887.1        2    0.019040           False     1.325248  ...
# cds-NP_254031.1        2    0.019040           False     1.325248  ...
# cds-NP_251541.1        2    0.019040           False     1.325248  ...
# cds-NP_249343.1        2    0.019040           False     1.325248  ...
# cds-NP_254116.1        2    0.019040           False     1.325248  ...
# cds-NP_250925.1        2    0.019040           False     1.325248  ...
# cds-NP_251683.1        2    0.019040           False     1.325248  ...
# cds-NP_249008.1        2    0.047695           False     0.057341  ...
# cds-NP_248996.1        2    0.019040           False     1.325248  ...
# cds-NP_253920.1        2    0.019040           False     1.325248  ...
# cds-NP_253623.1        2    0.019040           False     1.325248  ...
# cds-NP_253266.1        2    0.019040           False     1.325248  ...
# cds-NP_249398.1        2    0.019040           False     1.325248  ...
#
#                  Intercept_step1_sct  log_umi_step1_sct  dispersion_step1_sct  \
# cds-NP_252947.1            -3.358843           1.639634              0.038642
# cds-NP_252390.1            -1.392317          -1.083100              0.082877
# cds-NP_251877.1            -2.378695          -0.857115              0.005882
# cds-NP_250029.1             6.284802          -8.433281              0.003234
# cds-NP_253137.1            -2.671740          -0.419968              0.006068
# cds-NP_248707.1            -2.274203          -0.717703              0.006151
# cds-NP_252145.1            -2.214732          -0.762811              0.005872
# cds-NP_250461.1            -4.596730           1.290629              0.006407
# cds-NP_249783.1            -3.582754           1.859641              0.013886
# cds-NP_251331.1            -3.354048          -0.427998              0.006040
# cds-NP_252659.1             1.038036          -4.021405              0.003520
# cds-NP_253931.1            -1.945187          -1.512560              0.005287
# cds-NP_253887.1             2.447525          -5.272754              0.002738
# cds-NP_254031.1            -1.217502          -2.101681              0.004739
# cds-NP_251541.1            -3.655083          -0.206856              0.006106
# cds-NP_249343.1            -3.655083          -0.206856              0.006106
# cds-NP_254116.1            -0.259454          -2.901990              0.004462
# cds-NP_250925.1            -3.655083          -0.206856              0.006106
# cds-NP_251683.1             6.023521          -8.569149              0.001652
# cds-NP_249008.1             0.044823          -2.816290              0.173804
# cds-NP_248996.1             9.032626         -11.457185              0.002455
# cds-NP_253920.1            -1.491899          -1.877458              0.004942
# cds-NP_253623.1            -0.567742          -2.641709              0.004709
# cds-NP_253266.1             3.415606          -6.149317              0.002330
# cds-NP_249398.1            -0.259454          -2.901990              0.004462
#
#                      mean       std           lt  locus_tag  \
# cds-NP_252947.1 -0.093248  0.393075  NP_252947.1     PA4257
# cds-NP_252390.1 -2.972599  0.704859  NP_252390.1     PA3700
# cds-NP_251877.1 -0.951271  0.210587  NP_251877.1     PA3187
# cds-NP_250029.1 -0.938905  0.281971  NP_250029.1     PA1338
# cds-NP_253137.1 -0.726662  0.211962  NP_253137.1     PA4447
# cds-NP_248707.1 -0.724726  0.223305  NP_248707.1     PA0017
# cds-NP_252145.1 -0.725828  0.209182  NP_252145.1     PA3455
# cds-NP_250461.1 -0.241374  0.168747  NP_250461.1     PA1770
# cds-NP_249783.1  1.010368  0.163816  NP_249783.1     PA1092
# cds-NP_251331.1 -1.080739  0.171432  NP_251331.1     PA2641
# cds-NP_252659.1 -1.073721  0.221769  NP_252659.1     PA3970
# cds-NP_253931.1 -1.077660  0.193149  NP_253931.1     PA5244
# cds-NP_253887.1 -1.072705  0.228612  NP_253887.1     PA5200
# cds-NP_254031.1 -1.076397  0.202105  NP_254031.1     PA5344
# cds-NP_251541.1 -1.081361  0.168722  NP_251541.1     PA2851
# cds-NP_249343.1 -1.081361  0.168722  NP_249343.1     PA0652
# cds-NP_254116.1 -1.074984  0.213655  NP_254116.1     PA5429
# cds-NP_250925.1 -1.081361  0.168722  NP_250925.1     PA2235
# cds-NP_251683.1 -1.070799  0.242106  NP_251683.1     PA2993
# cds-NP_249008.1 -4.153244  0.658743  NP_249008.1     PA0317
# cds-NP_248996.1 -1.069372  0.254362  NP_248996.1     PA0305
# cds-NP_253920.1 -1.076848  0.198854  NP_253920.1     PA5233
# cds-NP_253623.1 -1.075350  0.211388  NP_253623.1     PA4936
# cds-NP_253266.1 -1.072128  0.232607  NP_253266.1     PA4576
# cds-NP_249398.1 -1.074984  0.213655  NP_249398.1     PA0707
#
#                  product_accession  \
# cds-NP_252947.1        NP_252947.1
# cds-NP_252390.1        NP_252390.1
# cds-NP_251877.1        NP_251877.1
# cds-NP_250029.1        NP_250029.1
# cds-NP_253137.1        NP_253137.1
# cds-NP_248707.1        NP_248707.1
# cds-NP_252145.1        NP_252145.1
# cds-NP_250461.1        NP_250461.1
# cds-NP_249783.1        NP_249783.1
# cds-NP_251331.1        NP_251331.1
# cds-NP_252659.1        NP_252659.1
# cds-NP_253931.1        NP_253931.1
# cds-NP_253887.1        NP_253887.1
# cds-NP_254031.1        NP_254031.1
# cds-NP_251541.1        NP_251541.1
# cds-NP_249343.1        NP_249343.1
# cds-NP_254116.1        NP_254116.1
# cds-NP_250925.1        NP_250925.1
# cds-NP_251683.1        NP_251683.1
# cds-NP_249008.1        NP_249008.1
# cds-NP_248996.1        NP_248996.1
# cds-NP_253920.1        NP_253920.1
# cds-NP_253623.1        NP_253623.1
# cds-NP_253266.1        NP_253266.1
# cds-NP_249398.1        NP_249398.1
#
#                                                               name symbol
# cds-NP_252947.1                           30S ribosomal protein S3   rpsC
# cds-NP_252390.1                                lysine--tRNA ligase   lysS
# cds-NP_251877.1                ABC transporter ATP-binding protein    NaN
# cds-NP_250029.1                       gamma-glutamyltranspeptidase    ggt
# cds-NP_253137.1              histidinol-phosphate aminotransferase  hisC1
# cds-NP_248707.1    Ribosomal RNA small subunit methyltransferase B    NaN
# cds-NP_252145.1                               hypothetical protein    NaN
# cds-NP_250461.1                       phosphoenolpyruvate synthase   ppsA
# cds-NP_249783.1                                   B-type flagellin   fliC
# cds-NP_251331.1                     NADH dehydrogenase I subunit F   nuoF
# cds-NP_252659.1                                   AMP nucleosidase    amn
# cds-NP_253931.1                               hypothetical protein    NaN
# cds-NP_253887.1                      osmolarity response regulator   amgR
# cds-NP_254031.1                          transcriptional regulator   oxyR
# cds-NP_251541.1                                elongation factor P    efp
# cds-NP_249343.1                            cAMP-regulatory protein    vfr
# cds-NP_254116.1                            aspartate ammonia-lyase   aspA
# cds-NP_250925.1                     biofilm formation protein PslE   pslE
# cds-NP_251683.1                               hypothetical protein    NaN
# cds-NP_249008.1                               hypothetical protein    NaN
# cds-NP_248996.1                               hypothetical protein    NaN
# cds-NP_253920.1                  flagellar basal body protein FliL    NaN
# cds-NP_253623.1  23S rRNA (guanosine(2251)-2'-O)-methyltransfer...    NaN
# cds-NP_253266.1                             ATP-dependent protease    NaN
# cds-NP_249398.1                     transcriptional regulator ToxR   toxR
#
# [25 rows x 23 columns]

# %%
data_gene.write(data_path + "/pseudomonas_data_processed.h5ad")
