# %%
# !pip install scanpy
# !pip install KDEpy
# !pip install leidenalg
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: scanpy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: anndata>=0.8 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.10.7)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.11.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.3.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.8.2)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.3)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.57.1+1.g1ff679645)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.24.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (23.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.6)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.12)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.2.0)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.12.0)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.0.0)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.14.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy) (4.66.1)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.6)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->scanpy) (1.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->scanpy) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.56->scanpy) (0.40.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->scanpy) (3.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy->scanpy) (1.16.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.10/dist-packages (from session-info->scanpy) (0.10.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: KDEpy in /usr/local/lib/python3.10/dist-packages (1.1.9)
# Requirement already satisfied: numpy<2.0,>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from KDEpy) (1.24.4)
# Requirement already satisfied: scipy<2.0,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from KDEpy) (1.12.0)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: leidenalg in /usr/local/lib/python3.10/dist-packages (0.10.2)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from leidenalg) (0.11.5)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.7.0)

# %% [markdown]
# # Generating summary figures for BacSC datasets

# %%
import pandas as pd
import scanpy as sc
import anndata as ad
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import scipy.sparse as sps
from scipy.stats import ranksums, spearmanr, kendalltau
import pickle as pkl

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import tools.util_probe as up
import tools.util as ut
import tools.NB_est as nb
import tools.countsplit as cs
import tools.ClusterDE as cd

import importlib

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Preprocessing
# ### Read data

# %%
dataset_name = "Klebs_antibiotics_BD"

data_path = "../../data/BacDrop"
data_gene = sc.read_h5ad(data_path + "/antibiotics_data_processed_3.h5ad")
data_gene_cluster = sc.read_h5ad(data_path + "/antibiotics_data_processed_cluster.h5ad")

result_path = "Klebs_antibiotics"
with open(result_path + "_scdeed/scdeed_rel_scores.pkl", "rb") as f:
    rel_scores = pkl.load(f)
with open(result_path + "_scdeed/scdeed_null_rel_scores.pkl", "rb") as f:
    null_rel_scores = pkl.load(f)
with open(result_path + "_scdeed/scdeed_reliabilities.pkl", "rb") as f:
    reliabilities = pkl.load(f)
    
mod_df = pd.read_csv(result_path + "_clustering/modularities.csv")
mod_df_wide = pd.read_csv(result_path + "_clustering/modularities_wide.csv")

data_null_gen = sc.read_h5ad(data_path + "/null_data_antibiotics_2.h5ad")

figure_path = data_path + "/figures_klebsiella_antibiotics"
if not os.path.exists(figure_path):
    os.makedirs(figure_path)

# %% [markdown]
# ## Single plots
# ### UMAPs

# %%
umap_seq_depth = sc.pl.umap(data_gene, color="total_counts", show=False, title="Sequencing depth", cmap="inferno")
plt.savefig(figure_path + "/umap_depth.svg", format="svg")
plt.show()

# %%
umap_clusters = sc.pl.umap(data_gene, color="leiden_opt", show=False, palette="tab10")
umap_clusters.axes.legend_.set_title("Cell type")
plt.savefig(figure_path + "/umap_clusters.svg", format="svg")
plt.show()

# %%
data_gene.obs["replicate2"] = data_gene.obs["replicate"].astype(str)
data_gene.obs["Sample"] = data_gene.obs[["treatment", "replicate2"]].agg(', '.join, axis=1)
data_gene.obs
# Out:
#                                 treatment  replicate  n_genes_by_counts  \
# AAAAAGCTGCGTAACCATCCCACATTGCA   meropenem          1                 58
# AAAAAGCTGCGTAAGTTACGCAGCTTACA   meropenem          1                 20
# AAAAAGCTGCGTAGAGGATGGTCGCTACG   meropenem          1                 22
# AAAAAGCTGCGTAGAGGATGGTCTAAGAA   meropenem          1                 15
# AAAAAGCTGCGTAGATCGTATCAATTCCT   meropenem          1                 23
# ...                                   ...        ...                ...
# TTTGGACGACCGCGCGTAAGGAAAGGTGC  gentamicin          2                 36
# TTTGGACGACCGCGCGTAAGGACAGGTGC  gentamicin          2                 16
# TTTGGACGACCGCGCGTACGGAAAGGTGC  gentamicin          2                 16
# TTTGGACGACCGCGNGTAAGGAAAGGTGC  gentamicin          2                 17
# TTTGGACGACCGCTGTTGACGACCAGAGA  gentamicin          2                 22
#
#                                log1p_n_genes_by_counts  total_counts  \
# AAAAAGCTGCGTAACCATCCCACATTGCA                 4.077537          58.0
# AAAAAGCTGCGTAAGTTACGCAGCTTACA                 3.044522          23.0
# AAAAAGCTGCGTAGAGGATGGTCGCTACG                 3.135494          24.0
# AAAAAGCTGCGTAGAGGATGGTCTAAGAA                 2.772589          15.0
# AAAAAGCTGCGTAGATCGTATCAATTCCT                 3.178054          26.0
# ...                                                ...           ...
# TTTGGACGACCGCGCGTAAGGAAAGGTGC                 3.610918          41.0
# TTTGGACGACCGCGCGTAAGGACAGGTGC                 2.833213          16.0
# TTTGGACGACCGCGCGTACGGAAAGGTGC                 2.833213          16.0
# TTTGGACGACCGCGNGTAAGGAAAGGTGC                 2.890372          17.0
# TTTGGACGACCGCTGTTGACGACCAGAGA                 3.135494          25.0
#
#                                log1p_total_counts  outlier  n_genes  \
# AAAAAGCTGCGTAACCATCCCACATTGCA            4.077538    False       58
# AAAAAGCTGCGTAAGTTACGCAGCTTACA            3.178054    False       20
# AAAAAGCTGCGTAGAGGATGGTCGCTACG            3.218876    False       22
# AAAAAGCTGCGTAGAGGATGGTCTAAGAA            2.772589    False       15
# AAAAAGCTGCGTAGATCGTATCAATTCCT            3.295837    False       23
# ...                                           ...      ...      ...
# TTTGGACGACCGCGCGTAAGGAAAGGTGC            3.737670    False       36
# TTTGGACGACCGCGCGTAAGGACAGGTGC            2.833213    False       16
# TTTGGACGACCGCGCGTACGGAAAGGTGC            2.833213    False       16
# TTTGGACGACCGCGNGTAAGGAAAGGTGC            2.890372    False       17
# TTTGGACGACCGCTGTTGACGACCAGAGA            3.258096    False       22
#
#                                total_counts_norm  total_counts_scale  \
# AAAAAGCTGCGTAACCATCCCACATTGCA      -11452.792858         -122.304139
# AAAAAGCTGCGTAAGTTACGCAGCTTACA      -11422.499507          -59.115969
# AAAAAGCTGCGTAGAGGATGGTCGCTACG      -11396.897335            5.173109
# AAAAAGCTGCGTAGAGGATGGTCTAAGAA      -11423.457668          -58.789935
# AAAAAGCTGCGTAGATCGTATCAATTCCT      -11403.966625           -7.230058
# ...                                          ...                 ...
# TTTGGACGACCGCGCGTAAGGAAAGGTGC      -11392.354868           30.326708
# TTTGGACGACCGCGCGTAAGGACAGGTGC      -11425.472233          -63.048596
# TTTGGACGACCGCGCGTACGGAAAGGTGC      -11426.769120          -64.615901
# TTTGGACGACCGCGNGTAAGGAAAGGTGC      -11424.365155          -55.825197
# TTTGGACGACCGCTGTTGACGACCAGAGA      -11404.951891          -14.464233
#
#                               embedding_reliability  reliability_score  \
# AAAAAGCTGCGTAACCATCCCACATTGCA             undefined           0.150544
# AAAAAGCTGCGTAAGTTACGCAGCTTACA           trustworthy           0.439246
# AAAAAGCTGCGTAGAGGATGGTCGCTACG             undefined           0.253788
# AAAAAGCTGCGTAGAGGATGGTCTAAGAA           trustworthy           0.631212
# AAAAAGCTGCGTAGATCGTATCAATTCCT           trustworthy           0.613044
# ...                                             ...                ...
# TTTGGACGACCGCGCGTAAGGAAAGGTGC             undefined           0.268881
# TTTGGACGACCGCGCGTAAGGACAGGTGC           trustworthy           0.426935
# TTTGGACGACCGCGCGTACGGAAAGGTGC           trustworthy           0.378954
# TTTGGACGACCGCGNGTAAGGAAAGGTGC             undefined           0.372614
# TTTGGACGACCGCTGTTGACGACCAGAGA             undefined           0.337612
#
#                                null_reliability_score leiden_opt replicate2  \
# AAAAAGCTGCGTAACCATCCCACATTGCA                0.292507          3          1
# AAAAAGCTGCGTAAGTTACGCAGCTTACA                0.273709          2          1
# AAAAAGCTGCGTAGAGGATGGTCGCTACG                0.375685          1          1
# AAAAAGCTGCGTAGAGGATGGTCTAAGAA                0.056452          0          1
# AAAAAGCTGCGTAGATCGTATCAATTCCT                0.248979          0          1
# ...                                               ...        ...        ...
# TTTGGACGACCGCGCGTAAGGAAAGGTGC                0.049659          2          2
# TTTGGACGACCGCGCGTAAGGACAGGTGC                0.107834          2          2
# TTTGGACGACCGCGCGTACGGAAAGGTGC                0.138595          2          2
# TTTGGACGACCGCGNGTAAGGAAAGGTGC                0.127117          2          2
# TTTGGACGACCGCTGTTGACGACCAGAGA                0.110298          2          2
#
#                                       Sample
# AAAAAGCTGCGTAACCATCCCACATTGCA   meropenem, 1
# AAAAAGCTGCGTAAGTTACGCAGCTTACA   meropenem, 1
# AAAAAGCTGCGTAGAGGATGGTCGCTACG   meropenem, 1
# AAAAAGCTGCGTAGAGGATGGTCTAAGAA   meropenem, 1
# AAAAAGCTGCGTAGATCGTATCAATTCCT   meropenem, 1
# ...                                      ...
# TTTGGACGACCGCGCGTAAGGAAAGGTGC  gentamicin, 2
# TTTGGACGACCGCGCGTAAGGACAGGTGC  gentamicin, 2
# TTTGGACGACCGCGCGTACGGAAAGGTGC  gentamicin, 2
# TTTGGACGACCGCGNGTAAGGAAAGGTGC  gentamicin, 2
# TTTGGACGACCGCTGTTGACGACCAGAGA  gentamicin, 2
#
# [19638 rows x 16 columns]

# %%
import matplotlib as mp

cmap = mp.cm.get_cmap('tab20')
cmap(5)
# Out:
# (0.596078431372549, 0.8745098039215686, 0.5411764705882353, 1.0)

# %%
from matplotlib import colormaps
cmap = mp.cm.get_cmap('tab20')

umap_clusters = sc.pl.umap(data_gene, color="Sample", show=False, palette=[cmap(i) for i in range(6)])
umap_clusters.axes.legend_.set_title("Cell type")
plt.show()

# %%
seq_depth_scatter = sc.pl.scatter(data_gene, x='total_counts', y='n_genes_by_counts', show=False, size=15, color="leiden_opt", palette="tab10")
plt.xlabel("Sequencing depth")
plt.ylabel("Number of unique genes")
seq_depth_scatter.legend_.set_title("Cell cluster")

plt.savefig(figure_path + "/seq_depth_scatter.svg", format="svg")

plt.show()

# %% [markdown]
# ### Violin plots

# %%
import re
data_gene.var["Gene"] = [data_gene.var.loc[x, "symbol"] if not pd.isna(data_gene.var.loc[x, "symbol"])
                         else x if pd.isna(data_gene.var.loc[x, "locus_tag"])
                         else data_gene.var.loc[x, "locus_tag"].split(r"_")[1]
                         for x in data_gene.var.index.tolist()]

data_gene.var
# Out:
#                     n_cells_by_counts  mean_counts  log1p_mean_counts  \
# cds-AF52_RS00165                   13     0.000662           0.000662
# cds-AF52_RS00180                    2     0.000102           0.000102
# cds-AF52_RS00620                   14     0.000713           0.000713
# cds-AF52_RS01010                    2     0.000102           0.000102
# cds-AF52_RS01075                    3     0.000153           0.000153
# ...                               ...          ...                ...
# cds-WP_187079188.1                  9     0.000458           0.000458
# cds-WP_187079189.1                 24     0.001273           0.001272
# cds-WP_187079194.1                 39     0.002037           0.002035
# cds-WP_187079196.1                 21     0.001171           0.001171
# cds-WP_187079197.1                 11     0.000560           0.000560
#
#                     pct_dropout_by_counts  total_counts  log1p_total_counts  \
# cds-AF52_RS00165                99.933802          13.0            2.639057
# cds-AF52_RS00180                99.989816           2.0            1.098612
# cds-AF52_RS00620                99.928710          14.0            2.708050
# cds-AF52_RS01010                99.989816           2.0            1.098612
# cds-AF52_RS01075                99.984723           3.0            1.386294
# ...                                   ...           ...                 ...
# cds-WP_187079188.1              99.954170           9.0            2.302585
# cds-WP_187079189.1              99.877788          25.0            3.258096
# cds-WP_187079194.1              99.801405          40.0            3.713572
# cds-WP_187079196.1              99.893064          23.0            3.178054
# cds-WP_187079197.1              99.943986          11.0            2.484907
#
#                     n_cells  var_counts  is_scd_outlier  nb_overdisp  ...  \
# cds-AF52_RS00165         13    0.000661           False     0.015929  ...
# cds-AF52_RS00180          2    0.000102           False     0.000202  ...
# cds-AF52_RS00620         14    0.000713           False     0.026059  ...
# cds-AF52_RS01010          2    0.000102           False     0.000202  ...
# cds-AF52_RS01075          3    0.000153           False     0.000238  ...
# ...                     ...         ...             ...          ...  ...
# cds-WP_187079188.1        9    0.000458           False     0.021694  ...
# cds-WP_187079189.1       24    0.001373           False     0.024587  ...
# cds-WP_187079194.1       39    0.002134           False     0.028569  ...
# cds-WP_187079196.1       21    0.001374           False     0.019140  ...
# cds-WP_187079197.1       11    0.000560           False     0.016529  ...
#
#                     highly_variable_rank     means  variances  variances_norm  \
# cds-AF52_RS00165                  2270.0  0.000662   0.000662        0.950712
# cds-AF52_RS00180                  1335.0  0.000102   0.000102        1.001273
# cds-AF52_RS00620                  2364.0  0.000713   0.000712        0.948014
# cds-AF52_RS01010                  1329.0  0.000102   0.000102        1.001273
# cds-AF52_RS01075                  1973.0  0.000153   0.000153        0.963435
# ...                                  ...       ...        ...             ...
# cds-WP_187079188.1                2484.0  0.000458   0.000458        0.944642
# cds-WP_187079189.1                1025.0  0.001273   0.001373        1.008768
# cds-WP_187079194.1                1578.0  0.002037   0.002135        0.986250
# cds-WP_187079196.1                 392.0  0.001171   0.001374        1.096998
# cds-WP_187079197.1                2135.0  0.000560   0.000560        0.953034
#
#                                 lt     locus_tag  product_accession  \
# cds-AF52_RS00165      AF52_RS00165  AF52_RS00165                NaN
# cds-AF52_RS00180      AF52_RS00180  AF52_RS00180                NaN
# cds-AF52_RS00620      AF52_RS00620  AF52_RS00620                NaN
# cds-AF52_RS01010      AF52_RS01010           NaN                NaN
# cds-AF52_RS01075      AF52_RS01075  AF52_RS01075                NaN
# ...                            ...           ...                ...
# cds-WP_187079188.1  WP_187079188.1  AF52_RS17635     WP_187079188.1
# cds-WP_187079189.1  WP_187079189.1  AF52_RS17360     WP_187079189.1
# cds-WP_187079194.1  WP_187079194.1  AF52_RS10645     WP_187079194.1
# cds-WP_187079196.1  WP_187079196.1  AF52_RS02875     WP_187079196.1
# cds-WP_187079197.1  WP_187079197.1  AF52_RS00900     WP_187079197.1
#
#                                                                  name  symbol  \
# cds-AF52_RS00165                                  diguanylate cyclase     NaN
# cds-AF52_RS00180                         PTS transporter subunit EIIC     NaN
# cds-AF52_RS00620            sugar ABC transporter ATP-binding protein     NaN
# cds-AF52_RS01010                                                  NaN     NaN
# cds-AF52_RS01075                               DUF5347 family protein     NaN
# ...                                                               ...     ...
# cds-WP_187079188.1                            DNA replication protein     NaN
# cds-WP_187079189.1                                     ribonuclease D     rnd
# cds-WP_187079194.1                                         ribokinase    rbsK
# cds-WP_187079196.1            6-carboxytetrahydropterin synthase QueD    queD
# cds-WP_187079197.1  bifunctional ADP-dependent NAD(P)H-hydrate deh...     nnr
#
#                                 Gene
# cds-AF52_RS00165             RS00165
# cds-AF52_RS00180             RS00180
# cds-AF52_RS00620             RS00620
# cds-AF52_RS01010    cds-AF52_RS01010
# cds-AF52_RS01075             RS01075
# ...                              ...
# cds-WP_187079188.1           RS17635
# cds-WP_187079189.1               rnd
# cds-WP_187079194.1              rbsK
# cds-WP_187079196.1              queD
# cds-WP_187079197.1               nnr
#
# [2500 rows x 29 columns]

# %%
n_genes = 20
clusters = data_gene.obs["leiden_opt"].unique().tolist()
clusters.sort()

fig, ax = plt.subplots(len(clusters), 1, figsize=(6, 3*len(clusters)))

i = 0
for c in clusters:
    plot_genes = data_gene_cluster.uns["ClusterDE_results"][c].iloc[:n_genes,:].index.tolist()
    violins = sc.pl.rank_genes_groups_violin(data_gene_cluster, gene_names=plot_genes, key="ClusterDE_results", groups=c, ax=ax[i], show=False)
    ax[i].set(xticklabels=data_gene.var.loc[plot_genes]["Gene"])
    
    i += 1
    
plt.tight_layout()
plt.savefig(figure_path + "/violin_plots.svg", format="svg")

plt.show()

# %% [markdown]
# ### Heatmap of highly differential genes

# %%
all_marker_genes = []
for c in clusters:
    plot_genes = data_gene_cluster.uns["ClusterDE_results"][c].iloc[:n_genes,:].index.tolist()
    all_marker_genes += plot_genes

heatmap_plot = sc.pl.heatmap(data_gene_cluster, all_marker_genes, groupby='leiden_opt', swap_axes=True, show_gene_labels=True, show=False, cmap="inferno")
heatmap_plot["groupby_ax"].set(xlabel="Cell cluster")

plt.savefig(figure_path + "/heatmap.svg", format="svg")

plt.show()

# %% [markdown]
# ### Volcano plots

# %%
fig, ax = plt.subplots(len(clusters), 1, figsize=(3, 3*len(clusters)))

i=0
for c in clusters:
    pvals_test = data_gene_cluster.uns["ClusterDE_results"][c]

    expr_gene_group_1 = data_gene[data_gene.obs["leiden_opt"] == c].layers["vst_counts"].copy().toarray()
    expr_gene_group_0 = data_gene[data_gene.obs["leiden_opt"] != c].layers["vst_counts"].copy().toarray()

    sum_group_0 = np.log2(np.mean(np.exp(expr_gene_group_0), axis=0) - (data_gene.var["nb_overdisp_cutoff"] / 4) + 1e-9)
    sum_group_1 = np.log2(np.mean(np.exp(expr_gene_group_1), axis=0) - (data_gene.var["nb_overdisp_cutoff"] / 4) + 1e-9)
    lfc = sum_group_1 - sum_group_0
    
    pvals_test["log2fold"] = lfc
    pvals_test["is_de"] = (pvals_test["q"] <= 0.05)
    pvals_test["log_q"] = -np.log10(pvals_test["q"])

    perc_zero_clust = (np.sum(data_gene_cluster[data_gene_cluster.obs["leiden_opt"] == c].layers["counts"].toarray() == 0, axis=0))/(data_gene_cluster[data_gene_cluster.obs["leiden_opt"] == c].shape[0])
    percent_zeros = pd.DataFrame({"perc_zero": perc_zero_clust}, index=data_gene_cluster.var_names)
    pvals_test["percent_zero"] = percent_zeros["perc_zero"]

    sns.scatterplot(pvals_test[pvals_test["percent_zero"] <= 0.95], x="log2fold", y="pval_trafo_data", hue="is_de", alpha=1, s=5, ax=ax[i])
    ax[i].set_title(f"Cluster {c}")
    ax[i].get_legend().remove()
    i += 1
    
plt.tight_layout()

# plt.savefig(figure_path + "/volcano_classic.svg", format="svg")

plt.show()

# %%
fig, ax = plt.subplots(len(clusters), 1, figsize=(3, 3*len(clusters)))

i = 0
for c in clusters:
    pvals_test = data_gene_cluster.uns["ClusterDE_results"][c]

    pvals_test["score_mean"] = (pvals_test["pval_trafo_data"] + pvals_test["pval_trafo_null"])/2
    pvals_test["is_de"] = (pvals_test["q"] <= 0.05)

    sns.scatterplot(pvals_test, x="score_mean", y="cs", hue="is_de", alpha=1, s=5, ax=ax[i])
    ax[i].set_title(f"Cluster {c}")
    ax[i].get_legend().remove()    
    i += 1

plt.tight_layout()
plt.savefig(figure_path + "/volcano_clusterde.svg", format="svg")

plt.show()

# %% [markdown]
# ## Combine subplots into one big figure

# %%
data_gene.var
# Out:
#                     n_cells_by_counts  mean_counts  log1p_mean_counts  \
# cds-AF52_RS00165                   13     0.000662           0.000662
# cds-AF52_RS00180                    2     0.000102           0.000102
# cds-AF52_RS00620                   14     0.000713           0.000713
# cds-AF52_RS01010                    2     0.000102           0.000102
# cds-AF52_RS01075                    3     0.000153           0.000153
# ...                               ...          ...                ...
# cds-WP_187079188.1                  9     0.000458           0.000458
# cds-WP_187079189.1                 24     0.001273           0.001272
# cds-WP_187079194.1                 39     0.002037           0.002035
# cds-WP_187079196.1                 21     0.001171           0.001171
# cds-WP_187079197.1                 11     0.000560           0.000560
#
#                     pct_dropout_by_counts  total_counts  log1p_total_counts  \
# cds-AF52_RS00165                99.933802          13.0            2.639057
# cds-AF52_RS00180                99.989816           2.0            1.098612
# cds-AF52_RS00620                99.928710          14.0            2.708050
# cds-AF52_RS01010                99.989816           2.0            1.098612
# cds-AF52_RS01075                99.984723           3.0            1.386294
# ...                                   ...           ...                 ...
# cds-WP_187079188.1              99.954170           9.0            2.302585
# cds-WP_187079189.1              99.877788          25.0            3.258096
# cds-WP_187079194.1              99.801405          40.0            3.713572
# cds-WP_187079196.1              99.893064          23.0            3.178054
# cds-WP_187079197.1              99.943986          11.0            2.484907
#
#                     n_cells  var_counts  is_scd_outlier  nb_overdisp  ...  \
# cds-AF52_RS00165         13    0.000661           False     0.015929  ...
# cds-AF52_RS00180          2    0.000102           False     0.000202  ...
# cds-AF52_RS00620         14    0.000713           False     0.026059  ...
# cds-AF52_RS01010          2    0.000102           False     0.000202  ...
# cds-AF52_RS01075          3    0.000153           False     0.000238  ...
# ...                     ...         ...             ...          ...  ...
# cds-WP_187079188.1        9    0.000458           False     0.021694  ...
# cds-WP_187079189.1       24    0.001373           False     0.024587  ...
# cds-WP_187079194.1       39    0.002134           False     0.028569  ...
# cds-WP_187079196.1       21    0.001374           False     0.019140  ...
# cds-WP_187079197.1       11    0.000560           False     0.016529  ...
#
#                     highly_variable  highly_variable_rank     means  \
# cds-AF52_RS00165               True                2270.0  0.000662
# cds-AF52_RS00180               True                1335.0  0.000102
# cds-AF52_RS00620               True                2364.0  0.000713
# cds-AF52_RS01010               True                1329.0  0.000102
# cds-AF52_RS01075               True                1973.0  0.000153
# ...                             ...                   ...       ...
# cds-WP_187079188.1             True                2484.0  0.000458
# cds-WP_187079189.1             True                1025.0  0.001273
# cds-WP_187079194.1             True                1578.0  0.002037
# cds-WP_187079196.1             True                 392.0  0.001171
# cds-WP_187079197.1             True                2135.0  0.000560
#
#                     variances  variances_norm              lt     locus_tag  \
# cds-AF52_RS00165     0.000662        0.950712    AF52_RS00165  AF52_RS00165
# cds-AF52_RS00180     0.000102        1.001273    AF52_RS00180  AF52_RS00180
# cds-AF52_RS00620     0.000712        0.948014    AF52_RS00620  AF52_RS00620
# cds-AF52_RS01010     0.000102        1.001273    AF52_RS01010           NaN
# cds-AF52_RS01075     0.000153        0.963435    AF52_RS01075  AF52_RS01075
# ...                       ...             ...             ...           ...
# cds-WP_187079188.1   0.000458        0.944642  WP_187079188.1  AF52_RS17635
# cds-WP_187079189.1   0.001373        1.008768  WP_187079189.1  AF52_RS17360
# cds-WP_187079194.1   0.002135        0.986250  WP_187079194.1  AF52_RS10645
# cds-WP_187079196.1   0.001374        1.096998  WP_187079196.1  AF52_RS02875
# cds-WP_187079197.1   0.000560        0.953034  WP_187079197.1  AF52_RS00900
#
#                     product_accession  \
# cds-AF52_RS00165                  NaN
# cds-AF52_RS00180                  NaN
# cds-AF52_RS00620                  NaN
# cds-AF52_RS01010                  NaN
# cds-AF52_RS01075                  NaN
# ...                               ...
# cds-WP_187079188.1     WP_187079188.1
# cds-WP_187079189.1     WP_187079189.1
# cds-WP_187079194.1     WP_187079194.1
# cds-WP_187079196.1     WP_187079196.1
# cds-WP_187079197.1     WP_187079197.1
#
#                                                                  name  symbol
# cds-AF52_RS00165                                  diguanylate cyclase     NaN
# cds-AF52_RS00180                         PTS transporter subunit EIIC     NaN
# cds-AF52_RS00620            sugar ABC transporter ATP-binding protein     NaN
# cds-AF52_RS01010                                                  NaN     NaN
# cds-AF52_RS01075                               DUF5347 family protein     NaN
# ...                                                               ...     ...
# cds-WP_187079188.1                            DNA replication protein     NaN
# cds-WP_187079189.1                                     ribonuclease D     rnd
# cds-WP_187079194.1                                         ribokinase    rbsK
# cds-WP_187079196.1            6-carboxytetrahydropterin synthase QueD    queD
# cds-WP_187079197.1  bifunctional ADP-dependent NAD(P)H-hydrate deh...     nnr
#
# [2500 rows x 28 columns]

# %%
n_genes = 10
clusters = data_gene.obs["leiden_opt"].unique().tolist()
clusters.sort()
n_clusters = len(clusters)

all_marker_genes = []
for c in clusters:
    plot_genes = data_gene_cluster.uns["ClusterDE_results"][c].iloc[:n_genes,:].index.tolist()
    all_marker_genes += plot_genes
    
all_marker_genes = list(dict.fromkeys(all_marker_genes))
heatmap_plot = sc.pl.heatmap(data_gene_cluster, all_marker_genes, groupby='leiden_opt', swap_axes=False, show_gene_labels=True, show=False, cmap="inferno", figsize=(9, 3*n_clusters))
heatmap_plot["groupby_ax"].set(ylabel="Cell cluster")
heatmap_plot["heatmap_ax"].set(xticklabels=data_gene.var.loc[all_marker_genes]["Gene"])
plt.tight_layout()
plt.savefig(figure_path + "/heatmap_temp.png", format="png", bbox_inches='tight', dpi=300)

# %%
n_subset = 200

data_subset = []
clusters = data_gene_cluster.obs["leiden_opt"].unique().tolist()
print(clusters)
for c in clusters:
    if len(data_gene_cluster[data_gene_cluster.obs["leiden_opt"] == c]) > n_subset:
        select_barcodes = data_gene_cluster[data_gene_cluster.obs["leiden_opt"] == c][:n_subset]
        data_subset.append(select_barcodes)
        
    else:
        data_subset.append(data_gene_cluster[data_gene_cluster.obs["leiden_opt"] == c])

data_subset = ad.concat(data_subset)
print(data_subset)
# Out:
# ['3', '2', '1', '0', '5', '4', '6', '7']
# AnnData object with n_obs × n_vars = 1341 × 2484
#     obs: 'treatment', 'replicate', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'outlier', 'n_genes', 'total_counts_norm', 'total_counts_scale', 'embedding_reliability', 'reliability_score', 'null_reliability_score', 'leiden_opt'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts', 'vst_counts'

# %%
import re
n_genes = 10
clusters = data_gene.obs["leiden_opt"].unique().tolist()
clusters.sort()
n_clusters = len(clusters)

all_marker_genes = []
for c in clusters:
    plot_genes = data_gene_cluster.uns["ClusterDE_results"][c].iloc[:n_genes,:].index.tolist()
    all_marker_genes += plot_genes
    
all_marker_genes = list(dict.fromkeys(all_marker_genes))
heatmap_plot = sc.pl.heatmap(data_subset, all_marker_genes, groupby='leiden_opt', swap_axes=False, show_gene_labels=True, show=False, cmap="inferno", figsize=(9, 3*n_clusters))
heatmap_plot["heatmap_ax"].set_xticklabels([data_gene.var.loc[x.get_text(), "Gene"] for x in heatmap_plot["heatmap_ax"].get_xticklabels()])
heatmap_plot["groupby_ax"].set(ylabel="Cell cluster")
plt.tight_layout()
plt.savefig(figure_path + "/heatmap_temp_reduced.png", format="png", bbox_inches='tight', dpi=300)

# %%
import matplotlib.transforms as mtransforms

# gridspec inside gridspec

fig = plt.figure(layout='constrained', figsize=(18, 3*n_clusters + 1))
subfigs = fig.subfigures(2, 1, hspace=0.07, height_ratios=[1, n_clusters])
subfigsTop = subfigs[0].subfigures(1, 4, wspace=0.07)

ax_pca = subfigsTop[0].subplots(1,1)
sc.pl.pca(data_gene, color="leiden_opt", show=False, ax=ax_pca, title="", legend_loc=None)

ax_umap_cluster = subfigsTop[1].subplots(1,1)
sc.pl.umap(data_gene, color="leiden_opt", show=False, palette="tab10", ax=ax_umap_cluster, title="", legend_loc=None)

ax_scatter = subfigsTop[2].subplots(1,1)
sc.pl.scatter(data_gene, x='total_counts', y='n_genes_by_counts', show=False, size=15, color="leiden_opt", palette="tab10", ax=ax_scatter, title="")
ax_scatter.set(xlabel="Sequencing depth", ylabel="Number of unique genes")
ax_scatter.legend_.set_title("Cell cluster")

ax_umap_seqdepth = subfigsTop[3].subplots(1,1) 
from matplotlib import colormaps
cmap = mp.cm.get_cmap('tab20')

umap_clusters = sc.pl.umap(data_gene, color="Sample", show=False, palette=[cmap(i) for i in range(6)], ax=ax_umap_seqdepth)
umap_clusters.axes.legend_.set_title("Sample")

subfigsBot = subfigs[1].subfigures(1, 3, wspace=0.07, width_ratios=[0.5, 1/3, 1/6])

all_marker_genes = []
n_genes=10
for c in clusters:
    plot_genes = data_gene_cluster.uns["ClusterDE_results"][c].iloc[:n_genes,:].index.tolist()
    all_marker_genes += plot_genes

heatmap_ax = subfigsBot[0].subplots(1, 1)

img = mpimg.imread(figure_path + "/heatmap_temp_reduced.png")
heatmap_ax.imshow(img)
heatmap_ax.axis('off')

axs_violin = subfigsBot[1].subplots(n_clusters, 1)

i = 0
for c in clusters:
    plot_genes = data_gene_cluster.uns["ClusterDE_results"][c].iloc[:n_genes,:].index.tolist()
    sc.pl.rank_genes_groups_violin(data_gene_cluster, gene_names=plot_genes, key="ClusterDE_results", groups=c, ax=axs_violin[i], show=False)
    axs_violin[i].set(xticklabels=data_gene.var.loc[plot_genes]["Gene"])
    
    i += 1

    
sc.tl.rank_genes_groups(data_gene_cluster, "leiden_opt", method="wilcoxon", layer="vst_counts")

axs_volcano = subfigsBot[2].subplots(n_clusters, 1)

i=0
for c in clusters:
    pvals_test = data_gene_cluster.uns["ClusterDE_results"][c]

    expr_gene_group_1 = data_gene[data_gene.obs["leiden_opt"] == c].layers["vst_counts"].copy().toarray()
    expr_gene_group_0 = data_gene[data_gene.obs["leiden_opt"] != c].layers["vst_counts"].copy().toarray()

    sum_group_0 = np.log2(np.mean(np.exp(expr_gene_group_0), axis=0) - (data_gene.var["nb_overdisp_cutoff"] / 4) + 1e-9)
    sum_group_1 = np.log2(np.mean(np.exp(expr_gene_group_1), axis=0) - (data_gene.var["nb_overdisp_cutoff"] / 4) + 1e-9)
    lfc = sum_group_1 - sum_group_0
    
    pvals_test["log2fold"] = lfc
    pvals_test["is_de"] = (pvals_test["q"] <= 0.05)

    perc_zero_clust = (np.sum(data_gene_cluster[data_gene_cluster.obs["leiden_opt"] == c].layers["counts"].toarray() == 0, axis=0))/(data_gene_cluster[data_gene_cluster.obs["leiden_opt"] == c].shape[0])
    percent_zeros = pd.DataFrame({"perc_zero": perc_zero_clust}, index=data_gene_cluster.var_names)
    pvals_test["percent_zero"] = percent_zeros["perc_zero"]

    sns.scatterplot(pvals_test[pvals_test["percent_zero"] <= 0.8], x="log2fold", y="pval_trafo_data", hue="is_de", alpha=1, s=5, ax=axs_volcano[i])
    axs_volcano[i].set_title(f"Cluster {c}")
    axs_volcano[i].get_legend().remove()
    axs_volcano[i].set(xlabel="log2-fold change", ylabel="-log10(p)")
    i += 1
    
axes = [ax_pca, ax_umap_cluster, ax_scatter, ax_umap_seqdepth, heatmap_ax, axs_violin, axs_volcano]
labels = ["A", "B", "C", "D", "E", "F", "G"]

for ax, label in zip(axes, labels):
    if type(ax) == np.ndarray:
        ax = ax[0]
    trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
    ax.text(0.0, 1.0, label, transform=ax.transAxes + trans,
            fontsize='medium', va='bottom', fontweight="bold")

plt.savefig(f"{figure_path}/{dataset_name}_summary_figure.svg", format="svg")
plt.savefig(f"{figure_path}/{dataset_name}_summary_figure.png", format="png", dpi=300)

plt.show()

# %% [markdown]
# ## Technical summary figure
#
# ### scTransform Theta parameters

# %%
g = sns.scatterplot(data=data_gene.var, y="nb_overdisp_cutoff", x="mean_counts")
g.set(xscale="log", yscale="log")
plt.title("Overdispersion parameters estimated by scTransform")
plt.xlabel("Gene mean")
plt.ylabel("Theta")
plt.show()

# %% [markdown]
# ### Sequencing depth distribution before and after VST

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 5))
p1 = sns.histplot(data_gene.obs, x="total_counts", kde=False, ax=axes[0], multiple="stack")
axes[0].set_title("Raw counts")
axes[0].set(xlabel="Sequencing depth")
data_gene.obs["total_counts_norm"] = data_gene.layers["vst_counts"].sum(1)
p2 = sns.histplot(data_gene.obs, x="total_counts_norm", kde=False, ax=axes[1], multiple="stack")
axes[1].set_title("After VST")
axes[1].set(xlabel="Sequencing depth")
data_gene.obs["total_counts_scale"] = data_gene.X.sum(1)
p2 = sns.histplot(data_gene.obs, x="total_counts_scale", kde=False, ax=axes[2], multiple="stack")
axes[2].set_title("VST and scaling")
axes[2].set(xlabel="Sequencing depth")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Latent dimensionality

# %%
k_opt = data_gene.uns["BacSC_params"]["k_opt"]
n_neighbors_opt = data_gene.uns["BacSC_params"]["n_neighbors_opt"]
min_dist_opt = data_gene.uns["BacSC_params"]["min_dist_opt"]
res_opt = data_gene.uns["BacSC_params"]["res_opt"]

# %%
is_overdispersed = False
data_dist = "Poi"
data_train, data_test = cs.countsplit_adata(data_gene, data_dist=data_dist, beta_key="nb_overdisp_cutoff", layer="counts", min_genes=1, max_counts=1e9, seed=1234)

# Transformation, centering and PCA
sc.pp.normalize_total(data_train, target_sum=None, layer=None)
if is_overdispersed:
    data_train.X = sps.csr_matrix(np.log(data_train.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
else:
    # data_train.X = sps.csr_matrix(np.sqrt(data_train.X.toarray()))
    data_train.X = sps.csr_matrix(np.log(data_train.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
data_train.layers["vst_counts"] = data_train.X.copy()
sc.pp.scale(data_train, max_value=10, zero_center=True)
sc.tl.pca(data_train, svd_solver='arpack')


sc.pp.normalize_total(data_test, target_sum=None, layer=None)
if is_overdispersed:
    data_test.X = sps.csr_matrix(np.log(data_test.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
else:
    # data_test.X = sps.csr_matrix(np.sqrt(data_test.X.toarray()))
    data_test.X = sps.csr_matrix(np.log(data_test.X.toarray() + np.array(data_train.var["nb_overdisp_cutoff"] / 4)))
data_test.layers["vst_counts"] = data_test.X.copy()
sc.pp.scale(data_test, max_value=10, zero_center=True)
sc.tl.pca(data_test, svd_solver='arpack')

k_errors, k_opt = cs.select_n_pcs_countsplit(data_train, data_test)
print(f"Optimal number of PCs:{k_opt}")
# Out:
# Optimal number of PCs:5

# %%
fig, ax = plt.subplots()
ax.scatter(np.arange(20) + 1, k_errors)
ax.set_title("SVD loss")
ax.set(xlabel="Dimensionality", ylabel="Test loss")
ax.set_xticks([5, 10, 15, 20])
plt.axvline(x=k_opt, color="red", linestyle="dashed")
plt.show()

# %% [markdown]
# ### scDEED results

# %%
param_df = pd.DataFrame({
    "n_neighbors": [x[0] for x in rel_scores.keys()],
    "min_dist": [x[1] for x in rel_scores.keys()],
    "mean_rel": [np.mean(x) for x in rel_scores.values()],
    "mean_null_rel": [np.mean(x) for x in null_rel_scores.values()],
    "num_dubious": [np.sum([y == "dubious" for y in x]) for x in reliabilities.values()],
    "num_trustworthy": [np.sum([y == "trustworthy" for y in x]) for x in reliabilities.values()],

})
n, p = data_gene.X.shape

param_df["share_dubious"] = param_df["num_dubious"] / n
param_df["share_trustworthy"] = param_df["num_trustworthy"] / n

fig, ax = plt.subplots()
sns.lineplot(data=param_df, x="n_neighbors", y="num_dubious", hue="min_dist", palette="tab10", ax=ax)
ax.set(title="scDEED results", ylabel="Number of dubiously embedded cells")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.legend_.set_title("min_dist")
plt.axvline(x=n_neighbors_opt, color="black", linestyle="dashed")
plt.show()

# %%
umap_reliability = sc.pl.umap(data_gene, color="embedding_reliability", alpha=1, title="", show=False, 
                              palette={"undefined": "tab:cyan", "trustworthy": "tab:blue", "dubious": "tab:red"}
                             )
umap_reliability.axes.legend_.set_title("Embedding reliability")
plt.show()

# %% [markdown]
# ### Clustering resolution

# %%
mod_df
# Out:
#     Unnamed: 0  resolution  n_clusters    type     score
# 0            0        0.01           1   train  0.490000
# 1            1        0.01           1    test  0.490000
# 2            2        0.01           1  random  0.490000
# 3            3        0.03           2   train  0.470525
# 4            4        0.03           2    test  0.444328
# ..         ...         ...         ...     ...       ...
# 70          70        0.47          10    test  0.065577
# 71          71        0.47          10  random  0.003920
# 72          72        0.49          10   train  0.336874
# 73          73        0.49          10    test  0.060658
# 74          74        0.49          10  random  0.001082
#
# [75 rows x 5 columns]

# %%
fig, ax = plt.subplots()
sns.lineplot(data=mod_df, x="resolution", y="score", hue="type", ax=ax)
ax.set(title="Clustering modularities", xlabel="Resolution", ylabel="Modularity")
ax.plot(
    [res_opt, res_opt], 
    [mod_df[(mod_df["resolution"] == res_opt) & (mod_df["type"] == "test")]["score"],
      mod_df[(mod_df["resolution"] == res_opt) & (mod_df["type"] == "random")]["score"]],
    linestyle="dashed", color="black"
)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
ax.legend_.set_title("Clustering")
plt.show()

sns.lineplot(data=mod_df_wide, x="resolution", y="diff_rand_test")
plt.title("Clustering modularities")
plt.xlabel("Resolution")
plt.ylabel("Difference Test-Random")
plt.show()

# %% [markdown]
# ### Combine plots

# %%
data_null_gen.obs
# Out:
#        n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# 0                     27                 3.332205          27.0
# 1                     20                 3.044522          24.0
# 2                     19                 2.995732          19.0
# 3                     19                 2.995732          22.0
# 4                     23                 3.178054          25.0
# ...                  ...                      ...           ...
# 39271                 26                 3.295837          30.0
# 39272                 22                 3.135494          24.0
# 39273                 26                 3.295837          27.0
# 39274                 13                 2.639057          15.0
# 39275                 26                 3.295837          30.0
#
#        log1p_total_counts leiden_0 leiden_best
# 0                3.332205        1           1
# 1                3.218876        0           0
# 2                2.995732        0           0
# 3                3.135494        1           1
# 4                3.258097        0           0
# ...                   ...      ...         ...
# 39271            3.433987        0           0
# 39272            3.218876        0           0
# 39273            3.332205        1           1
# 39274            2.772589        0           0
# 39275            3.433987        0           0
#
# [39276 rows x 6 columns]

# %%
fig = plt.figure(layout='constrained', figsize=(20, 26))
subfigs = fig.subfigures(4, 1, hspace=0.07, height_ratios=[1, 2, 1, 1.5])

subfigs_vst = subfigs[0].subplots(1, 3)

p1 = sns.histplot(data_gene.obs, x="total_counts", kde=False, ax=subfigs_vst[0], multiple="stack", bins=100)
subfigs_vst[0].set_title("Raw counts")
subfigs_vst[0].set(xlabel="Sequencing depth")
data_gene.obs["total_counts_norm"] = data_gene.layers["vst_counts"].sum(1)
p2 = sns.histplot(data_gene.obs, x="total_counts_norm", kde=False, ax=subfigs_vst[1], multiple="stack", bins=100)
subfigs_vst[1].set_title("After VST")
subfigs_vst[1].set(xlabel="Sequencing depth")
data_gene.obs["total_counts_scale"] = data_gene.X.sum(1)
p2 = sns.histplot(data_gene.obs, x="total_counts_scale", kde=False, ax=subfigs_vst[2], multiple="stack", bins=100)
subfigs_vst[2].set_title("VST and scaling")
subfigs_vst[2].set(xlabel="Sequencing depth")

subfigs[0].suptitle("Variance stabilization")

subfigs_params = subfigs[1].subplots(2,2)

subfigs_params[0,0].scatter(np.arange(20) + 1, k_errors)
subfigs_params[0,0].set_title("Dimensionality reduction (count splitting)")
subfigs_params[0,0].set(xlabel="k", ylabel="Test loss")
subfigs_params[0,0].set_xticks([5, 10, 15, 20])
subfigs_params[0,0].axvline(x=k_opt, color="black", linestyle="dashed")

sns.lineplot(data=param_df, x="n_neighbors", y="num_dubious", hue="min_dist", palette="tab10", ax=subfigs_params[1,0])
subfigs_params[1,0].set(title="scDEED results", ylabel="Number of dubiously embedded cells")
sns.move_legend(subfigs_params[1,0], "upper left", bbox_to_anchor=(1, 1))
subfigs_params[1,0].legend_.set_title("min_dist")
subfigs_params[1,0].axvline(x=n_neighbors_opt, color="black", linestyle="dashed")

data_gene.obs["embedding_reliability"] = data_gene.obs["embedding_reliability"].cat.reorder_categories(['undefined', 'trustworthy', 'dubious'])
cmap = {"undefined": "tab:cyan", "trustworthy": "tab:blue", "dubious": "tab:red"}
sc.pl.umap(data_gene, color="embedding_reliability", alpha=1, title="", show=False, ax=subfigs_params[1,1], palette=cmap)
subfigs_params[1,1].legend_.set_title("Embedding reliability")

sns.lineplot(data=mod_df, x="resolution", y="score", hue="type", ax=subfigs_params[0,1])
subfigs_params[0,1].set(title="Clustering modularities", xlabel="Resolution", ylabel="Modularity")
subfigs_params[0,1].plot(
    [res_opt, res_opt], 
    [mod_df[(mod_df["resolution"] == res_opt) & (mod_df["type"] == "test")]["score"],
      mod_df[(mod_df["resolution"] == res_opt) & (mod_df["type"] == "random")]["score"]],
    linestyle="dashed", color="black"
)
sns.move_legend(subfigs_params[0,1], "upper left", bbox_to_anchor=(1, 1))
subfigs_params[0,1].legend_.set_title("Clustering")

subfigs[1].suptitle("Embedding parameters")

subfigs_null_data = subfigs[2].subplots(1, 3)

mean_df_opt = pd.DataFrame({"original_means": data_gene_cluster.var["mean_counts"], "null_means": data_null_gen.var["mean_counts"]})
sns.scatterplot(mean_df_opt, y="null_means", x="original_means", ax=subfigs_null_data[0])
subfigs_null_data[0].plot([0, np.ceil(np.max(data_gene_cluster.var["mean_counts"]))], [0, np.ceil(np.max(data_gene_cluster.var["mean_counts"]))], color="red")
subfigs_null_data[0].set_title("Gene mean comparison")

var_df_opt = pd.DataFrame({"original_vars": data_gene_cluster.var["var_counts"], "null_vars": data_null_gen.var["var_counts"]})
g = sns.scatterplot(var_df_opt, y="null_vars", x="original_vars", ax=subfigs_null_data[1])
g.set(xscale="log", yscale="log")
subfigs_null_data[1].plot([0, np.ceil(np.max(data_gene_cluster.var["var_counts"]))], [0, np.ceil(np.max(data_gene_cluster.var["var_counts"]))], color="red")
subfigs_null_data[1].set_title("Gene variance comparison")

sc.pl.umap(data_null_gen, color="leiden_best", alpha=1, title="Null data", show=False, ax=subfigs_null_data[2])
subfigs_null_data[2].legend_.set_title("Cluster")

subfigs[2].suptitle("Synthetic null data")

pvals_log_gen = data_gene_cluster.uns["ClusterDE_results"]
clusters = data_gene_cluster.obs["leiden_opt"].unique().tolist()
clusters.sort()
n_clusters = len(clusters)
subfigs_clusterde = subfigs[3].subplots(2, n_clusters)

i = 0
for c in clusters:
    sns.histplot(pvals_log_gen[c], x="pval_data", ax=subfigs_clusterde[0,i], bins=100)
    subfigs_clusterde[0,i].set_title(f"Cluster {c} p-values")
    
    sns.histplot(pvals_log_gen[c], x="cs", ax=subfigs_clusterde[1,i], bins=100)
    subfigs_clusterde[1,i].set_title(f"Cluster {c} contrast scores")
    subfigs_clusterde[1,i].set(ylim=(0, 250))
    if np.min(pvals_log_gen[c]["q"]) <= 0.05:
        cutoff = np.min(pvals_log_gen[c][pvals_log_gen[c]["q"] <= 0.05]["cs"])
        subfigs_clusterde[1,i].axvline(x=cutoff, color="black", linestyle="dashed")
    
    i += 1

subfigs[3].suptitle("ClusterDE")

axes = [subfigs_vst, subfigs_params[0,0], subfigs_params[0,1], subfigs_params[1,0], subfigs_params[1,1], subfigs_null_data[0], subfigs_null_data[1], subfigs_null_data[2], subfigs_clusterde[0,0], subfigs_clusterde[1,0]]
labels = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]

for ax, label in zip(axes, labels):
    if type(ax) == np.ndarray:
        ax = ax[0]
    trans = mtransforms.ScaledTranslation(-20/72, 7/72, fig.dpi_scale_trans)
    ax.text(0.0, 1.0, label, transform=ax.transAxes + trans,
            fontsize='medium', va='bottom', fontweight="bold")

fig.suptitle('Klebsiella 3 antibiotics', fontsize='xx-large')
plt.savefig(f"{figure_path}/{dataset_name}_technical_figure.svg", format="svg")
plt.savefig(f"{figure_path}/{dataset_name}_technical_figure.png", format="png", dpi=300)
plt.show()

# %% [markdown]
# ## DE table

# %%
cde_res = data_gene_cluster.uns["ClusterDE_results"]

# %%
cde_res["2"]["q"]
# Out:
# cds-WP_004145074.1      0.052632
# cds-WP_004146997.1      0.052632
# cds-WP_004151523.1      0.052632
# cds-WP_002885441.1      0.052632
# cds-WP_001181005.1      0.052632
#                           ...
# cds-WP_002919759.1      1.000000
# cds-WP_002914769.1      1.000000
# cds-WP_002919257.1      1.000000
# cds-WP_004174069.1      1.000000
# cds-WP_004174069.1-2    1.000000
# Name: q, Length: 2484, dtype: float64

# %%
clusters = list(cde_res.keys())[:-1]
print(clusters)

cluster_ana_table = pd.DataFrame({
    "Number of cells": [len(data_gene.obs[data_gene.obs["leiden_opt"] == c]) for c in clusters],
    "minimal q": [np.min(cde_res[c]["q"]) for c in clusters],
    "DE genes, FDR = 0.05": [len(cde_res[c][cde_res[c]["q"] < 0.05]) for c in clusters],
    "DE genes, FDR = 0.1": [len(cde_res[c][cde_res[c]["q"] < 0.1]) for c in clusters],
    "DE genes, FDR = 0.2": [len(cde_res[c][cde_res[c]["q"] < 0.2]) for c in clusters],
}, index=pd.Index(clusters, name="Cell Type"))
cluster_ana_table
# Out:
# ['0', '1', '2', '3', '4', '5', '6', '7']
#            Number of cells  minimal q  DE genes, FDR = 0.05  \
# Cell Type
# 0                     7954   0.076923                     0
# 1                     5960   0.102564                     0
# 2                     3262   0.052632                     0
# 3                     1843   0.016129                    96
# 4                      255   0.111111                     0
# 5                      223   0.029412                    69
# 6                       74   0.016667                   102
# 7                       67   0.012987                   102
#
#            DE genes, FDR = 0.1  DE genes, FDR = 0.2
# Cell Type
# 0                           13                   25
# 1                            0                  111
# 2                           62                  667
# 3                          122                  673
# 4                            0                   41
# 5                           83                  113
# 6                          121                  160
# 7                          118                  133

# %%
print(cluster_ana_table.reset_index().to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# Cell Type &  Number of cells &  minimal q &  DE genes, FDR = 0.05 &  DE genes, FDR = 0.1 &  DE genes, FDR = 0.2 \\
# \midrule
#         0 &             7954 &   0.076923 &                     0 &                   13 &                   25 \\
#         1 &             5960 &   0.102564 &                     0 &                    0 &                  111 \\
#         2 &             3262 &   0.052632 &                     0 &                   62 &                  667 \\
#         3 &             1843 &   0.016129 &                    96 &                  122 &                  673 \\
#         4 &              255 &   0.111111 &                     0 &                    0 &                   41 \\
#         5 &              223 &   0.029412 &                    69 &                   83 &                  113 \\
#         6 &               74 &   0.016667 &                   102 &                  121 &                  160 \\
#         7 &               67 &   0.012987 &                   102 &                  118 &                  133 \\
# \bottomrule
# \end{tabular}

# %%
all_marker_genes = []
for c in clusters:
    plot_genes = data_gene_cluster.uns["ClusterDE_results"][c].iloc[:n_genes,:].index.tolist()
    all_marker_genes += plot_genes
    print(f"Cluster {c}")
    print(data_gene.var.loc[plot_genes, ["locus_tag", "name", "symbol"]])
# Out:
# Cluster 0
#                           locus_tag  \
# cds-WP_004145074.1     AF52_RS10375
# cds-WP_004151070.1     AF52_RS02780
# cds-WP_013815099.1-79  AF52_RS22855
# cds-WP_002898162.1     AF52_RS11610
# cds-WP_004901914.1     AF52_RS04675
# cds-WP_002898408.1     AF52_RS11390
# cds-WP_032430155.1     AF52_RS07220
# cds-WP_002885441.1     AF52_RS06860
# cds-WP_002888735.1     AF52_RS06235
# cds-WP_002919515.1     AF52_RS08350
#
#                                                                     name  \
# cds-WP_004145074.1                             heat shock chaperone IbpB
# cds-WP_004151070.1                HAAAP family serine/threonine permease
# cds-WP_013815099.1-79         IS5-like element IS903B family transposase
# cds-WP_002898162.1                              30S ribosomal protein S1
# cds-WP_004901914.1              DNA-directed RNA polymerase subunit beta
# cds-WP_002898408.1                                            porin OmpA
# cds-WP_032430155.1               Fe(3+) dicitrate transport protein FecA
# cds-WP_002885441.1                                      chaperonin GroEL
# cds-WP_002888735.1     bifunctional aconitate hydratase 2/2-methyliso...
# cds-WP_002919515.1                   preprotein translocase subunit SecY
#
#                       symbol
# cds-WP_004145074.1      ibpB
# cds-WP_004151070.1       NaN
# cds-WP_013815099.1-79    NaN
# cds-WP_002898162.1      rpsA
# cds-WP_004901914.1      rpoB
# cds-WP_002898408.1      ompA
# cds-WP_032430155.1      fecA
# cds-WP_002885441.1      groL
# cds-WP_002888735.1      acnB
# cds-WP_002919515.1      secY
# Cluster 1
#                        locus_tag  \
# cds-WP_004151070.1  AF52_RS02780
# cds-WP_050484295.1  AF52_RS01185
# cds-WP_002920103.1  AF52_RS08480
# cds-WP_002913016.1  AF52_RS15760
# cds-WP_004144995.1  AF52_RS10550
# cds-WP_004179067.1  AF52_RS12635
# cds-WP_004174069.1  AF52_RS08475
# cds-WP_032430362.1  AF52_RS01180
# cds-WP_004145074.1  AF52_RS10375
# cds-WP_004146620.1  AF52_RS05095
#
#                                                                  name symbol
# cds-WP_004151070.1             HAAAP family serine/threonine permease    NaN
# cds-WP_050484295.1                                ATP-binding protein    NaN
# cds-WP_002920103.1                                elongation factor G   fusA
# cds-WP_002913016.1  ribonucleoside-diphosphate reductase subunit a...   nrdA
# cds-WP_004144995.1                    F0F1 ATP synthase subunit alpha   atpA
# cds-WP_004179067.1       succinate dehydrogenase flavoprotein subunit   sdhA
# cds-WP_004174069.1                               elongation factor Tu    tuf
# cds-WP_032430362.1                     DNA cytosine methyltransferase    NaN
# cds-WP_004145074.1                          heat shock chaperone IbpB   ibpB
# cds-WP_004146620.1                      excinuclease ABC subunit UvrA   uvrA
# Cluster 2
#                        locus_tag                                       name  \
# cds-WP_004145074.1  AF52_RS10375                  heat shock chaperone IbpB
# cds-WP_004146997.1  AF52_RS06780                   molecular chaperone DnaK
# cds-WP_004151523.1  AF52_RS10380                  heat shock chaperone IbpA
# cds-WP_002885441.1  AF52_RS06860                           chaperonin GroEL
# cds-WP_001181005.1  AF52_RS08455                  30S ribosomal protein S10
# cds-WP_002920103.1  AF52_RS08480                        elongation factor G
# cds-WP_004901914.1  AF52_RS04675   DNA-directed RNA polymerase subunit beta
# cds-WP_002884036.1  AF52_RS04660                   50S ribosomal protein L1
# cds-WP_002884146.1  AF52_RS04680  DNA-directed RNA polymerase subunit beta'
# cds-WP_000829818.1  AF52_RS08045                   30S ribosomal protein S9
#
#                    symbol
# cds-WP_004145074.1   ibpB
# cds-WP_004146997.1   dnaK
# cds-WP_004151523.1   ibpA
# cds-WP_002885441.1   groL
# cds-WP_001181005.1   rpsJ
# cds-WP_002920103.1   fusA
# cds-WP_004901914.1   rpoB
# cds-WP_002884036.1   rplA
# cds-WP_002884146.1   rpoC
# cds-WP_000829818.1   rpsI
# Cluster 3
#                             locus_tag  \
# cds-WP_013815099.1-79    AF52_RS22855
# cds-WP_032430171.1       AF52_RS24890
# cds-WP_004174069.1       AF52_RS08475
# cds-WP_032430073.1       AF52_RS09075
# cds-WP_004174069.1-2     AF52_RS08475
# cds-WP_002920103.1       AF52_RS08480
# cds-AF52_RS0123810     AF52_RS0123810
# cds-AF52_RS27655         AF52_RS27655
# cds-WP_002919515.1       AF52_RS08350
# cds-WP_002919219.1       AF52_RS08335
#
#                                                              name symbol
# cds-WP_013815099.1-79  IS5-like element IS903B family transposase    NaN
# cds-WP_032430171.1                         IS5 family transposase    NaN
# cds-WP_004174069.1                           elongation factor Tu    tuf
# cds-WP_032430073.1     IS5-like element IS903B family transposase    NaN
# cds-WP_004174069.1-2                         elongation factor Tu    tuf
# cds-WP_002920103.1                            elongation factor G   fusA
# cds-AF52_RS0123810      IS5-like element IS903 family transposase    NaN
# cds-AF52_RS27655                    IS5/IS1182 family transposase    NaN
# cds-WP_002919515.1            preprotein translocase subunit SecY   secY
# cds-WP_002919219.1      DNA-directed RNA polymerase subunit alpha   rpoA
# Cluster 4
#                          locus_tag  \
# cds-WP_020806188.1-6  AF52_RS19630
# cds-WP_020806188.1-4  AF52_RS19630
# cds-WP_020806188.1-2  AF52_RS19630
# cds-WP_020806188.1-5  AF52_RS19630
# cds-WP_020806188.1-3  AF52_RS19630
# cds-WP_002884808.1    AF52_RS05010
# cds-WP_002919773.1    AF52_RS08425
# cds-AF52_RS26885      AF52_RS26885
# cds-WP_004148860.1    AF52_RS17090
# cds-WP_020801659.1    AF52_RS16425
#
#                                                                    name symbol
# cds-WP_020806188.1-6        IS5-like element ISKpn26 family transposase    NaN
# cds-WP_020806188.1-4        IS5-like element ISKpn26 family transposase    NaN
# cds-WP_020806188.1-2        IS5-like element ISKpn26 family transposase    NaN
# cds-WP_020806188.1-5        IS5-like element ISKpn26 family transposase    NaN
# cds-WP_020806188.1-3        IS5-like element ISKpn26 family transposase    NaN
# cds-WP_002884808.1              4-hydroxybenzoate octaprenyltransferase   ubiA
# cds-WP_002919773.1                            50S ribosomal protein L22   rplV
# cds-AF52_RS26885                          IS5/IS1182 family transposase    NaN
# cds-WP_004148860.1    Holliday junction branch migration DNA helicas...   ruvB
# cds-WP_020801659.1              oligosaccharide flippase family protein    NaN
# Cluster 5
#                             locus_tag  \
# cds-AF52_RS26730         AF52_RS26730
# cds-AF52_RS27390         AF52_RS27390
# cds-AF52_RS0123810     AF52_RS0123810
# cds-AF52_RS27410         AF52_RS27410
# cds-AF52_RS26960         AF52_RS26960
# cds-WP_032430073.1       AF52_RS09075
# cds-AF52_RS08255         AF52_RS08255
# cds-WP_013815099.1-79    AF52_RS22855
# cds-WP_004174069.1       AF52_RS08475
# cds-WP_002920103.1       AF52_RS08480
#
#                                                              name symbol
# cds-AF52_RS26730                    IS5/IS1182 family transposase    NaN
# cds-AF52_RS27390                    IS5/IS1182 family transposase    NaN
# cds-AF52_RS0123810      IS5-like element IS903 family transposase    NaN
# cds-AF52_RS27410                    IS5/IS1182 family transposase    NaN
# cds-AF52_RS26960                    IS5/IS1182 family transposase    NaN
# cds-WP_032430073.1     IS5-like element IS903B family transposase    NaN
# cds-AF52_RS08255                    IS5/IS1182 family transposase    NaN
# cds-WP_013815099.1-79  IS5-like element IS903B family transposase    NaN
# cds-WP_004174069.1                           elongation factor Tu    tuf
# cds-WP_002920103.1                            elongation factor G   fusA
# Cluster 6
#                        locus_tag  \
# cds-WP_002898303.1  AF52_RS11445
# cds-WP_002915934.1  AF52_RS27535
# cds-WP_004140277.1  AF52_RS22040
# cds-WP_002882755.1  AF52_RS03780
# cds-WP_002883016.1  AF52_RS04120
# cds-WP_002910443.1  AF52_RS17870
# cds-WP_000124850.1  AF52_RS18185
# cds-WP_004149864.1  AF52_RS01230
# cds-WP_004185139.1  AF52_RS14585
# cds-WP_004192475.1  AF52_RS00835
#
#                                                               name symbol
# cds-WP_002898303.1  quinone-dependent dihydroorotate dehydrogenase   pyrD
# cds-WP_002915934.1       prolipoprotein diacylglyceryl transferase    lgt
# cds-WP_004140277.1                        enoyl-ACP reductase FabI   fabI
# cds-WP_002882755.1                  ribosome-dependent GTPase TypA   typA
# cds-WP_002883016.1          Si-specific NAD(P)(+) transhydrogenase   sthA
# cds-WP_002910443.1                     redox-regulated ATPase YchF   ychF
# cds-WP_000124850.1                       50S ribosomal protein L20   rplT
# cds-WP_004149864.1                                     DNA primase   dnaG
# cds-WP_004185139.1      phosphoribosylformylglycinamidine synthase   purL
# cds-WP_004192475.1                                  ribonuclease R    rnr
# Cluster 7
#                        locus_tag  \
# cds-WP_004151452.1  AF52_RS17025
# cds-WP_002883016.1  AF52_RS04120
# cds-WP_004178647.1  AF52_RS05885
# cds-WP_002914769.1  AF52_RS03305
# cds-WP_004174799.1  AF52_RS03575
# cds-WP_002912878.1  AF52_RS16025
# cds-WP_012068464.1  AF52_RS12625
# cds-WP_002919766.1  AF52_RS08420
# cds-WP_002913953.1  AF52_RS14720
# cds-WP_004142209.1  AF52_RS12620
#
#                                                                  name symbol
# cds-WP_004151452.1                              arginine--tRNA ligase   argS
# cds-WP_002883016.1             Si-specific NAD(P)(+) transhydrogenase   sthA
# cds-WP_004178647.1  acyl-ACP--UDP-N-acetylglucosamine O-acyltransf...   lpxA
# cds-WP_002914769.1                                   recombinase RecA   recA
# cds-WP_004174799.1                            DNA repair protein RecN   recN
# cds-WP_002912878.1  galactose/glucose ABC transporter substrate-bi...   mglB
# cds-WP_012068464.1          2-oxoglutarate dehydrogenase E1 component   sucA
# cds-WP_002919766.1                           30S ribosomal protein S3   rpsC
# cds-WP_002913953.1                                aminopeptidase PepB   pepB
# cds-WP_004142209.1  2-oxoglutarate dehydrogenase complex dihydroli...   odhB
